# %% [markdown]
# # Capstone Project 1: Track genre classification based on its audio features

# %% [markdown]
# ## Overview
#
# To re-write...

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import requests
import json
import helper
import warnings
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.colors import ListedColormap
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, auc, mean_squared_error
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.pipeline import make_pipeline
from sklearn import svm, datasets
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from itertools import cycle

warnings.filterwarnings("ignore")
sns.set()

# %% [markdown]
# Link for token generation:
# https://developer.spotify.com/console/get-current-user-playlists/?limit=&offset=

# %%
# Token needs to be generated everytime; will expire after a while...
token = "BQDS1zS_ygEgbnDMYdjSZjKC3x3lGWboojoHOW-WR0JrgQDR-iDjhFXfd_sc5QjH3L4dVQJNWCulv6h2jirdlzcddFXkq68Xbly458nO0y55UOU10siYZxLTyy9yeizh50T69f99wCoTVPNDpFgNPWW3kHYtoN3GrWmE-6uFAnrS25QfLEO6NY9uSyUKT5HhFEcVtlevd0nUTiZBaYckqjGCuIdJfKnQ9nOazMfcG_xbdSeyFrdt6C3-mNJqBpS9AEk_8R0x4-dDXsqcQqI"

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# This section is primarily used for wrangling the data that can be procured through the Spotify API. Because the coding can get complex, I've decided to create a helper.py that contains python methods that are used to wrangle the data. Please see the file for the code and more information on each method to help wrangle the Spotify data.

# %%
helper.get_playlist_list(token) # get the names of the playlists to use
# Out:
# [('5xOh7ZScLfijnSuZC7jKbY', 'rock'),
#  ('1eE7grg1fspxFTzcaqnr7H', 'classical'),
#  ('6s5PLDbBCiJB2H3ksvd7eW', 'country'),
#  ('1FbnYjA107nOCwSMxEClWy', 'hiphop'),
#  ('68JKNex2kXZDXrZKYwqi4u', 'pop'),
#  ('4EoPt05ztUjVaujcWbUL2Z', 'Sad Songs😔'),
#  ('37i9dQZF1DX7qK8ma5wgG1', 'Sad Songs'),
#  ('37i9dQZEVXcNWoAeZmqp3t', 'Discover Weekly'),
#  ('37i9dQZF1DX3rxVfibe1L0', 'Mood Booster'),
#  ('37i9dQZF1DX9XIFQuFvzM4', "Feelin' Good"),
#  ('37i9dQZF1DWSqBruwoIXkA', 'Down In The Dumps'),
#  ('37i9dQZF1DX0UrRvztWcAU', 'Wake Up Happy'),
#  ('37i9dQZF1DX3YSRoSdA634', 'Life Sucks'),
#  ('37i9dQZF1DXdPec7aLTmlC', 'Happy Hits!'),
#  ('0qa7LLPhZYtiAyPTyhdruH', 'The Best Of: The Front Bottoms'),
#  ('29rqX3FuqPWpoIRfrGG5Lp', 'New Playlist 2'),
#  ('3ORT0tbZTBE5TuRt21iRX6', 'La Verbena 2018'),
#  ('6eHO8aX6lHu3e6bem8r2rq', 'lofi hip hop music - beats to relax/study to'),
#  ('64OX1gQhI2NZxjPb4z3erl', 'Dance Yourself Clean - Official Playlist'),
#  ('37i9dQZF1DWSKpvyAAcaNZ', 'Blues & Roots Rock')]

# %% [markdown]
# In order to get the tracks, a playlist of each genre was made to house each of the tracks. One advantage of this is that each track can be easily labeled by its playlist name, which I named after each genre. This is useful for any classification techniques to be employed later in this project. Each track was added using Spotify's recommender system and was screened for correctness.

# %%
# playlist ids of the playlists containing the songs of each genre for classification
classical_id = '1eE7grg1fspxFTzcaqnr7H'
country_id = '6s5PLDbBCiJB2H3ksvd7eW' 
rock_id = '5xOh7ZScLfijnSuZC7jKbY' 
hiphop_id = '1FbnYjA107nOCwSMxEClWy'
pop_id = '68JKNex2kXZDXrZKYwqi4u'

# %%
classical_df = helper.get_df_from_playlist(classical_id, token).reset_index().drop_duplicates('id')

# %%
country_df = helper.get_df_from_playlist(country_id, token).drop_duplicates('id')

# %%
rock_df = helper.get_df_from_playlist(rock_id, token).drop_duplicates('id')

# %%
hiphop_df = helper.get_df_from_playlist(hiphop_id, token).drop_duplicates('id')

# %%
pop_df = helper.get_df_from_playlist(pop_id, token).drop_duplicates('id')

# %%
# Confirm that each df has the same amount of tracks.

print('The classical dataframe has', classical_df.name.count(), 'tracks')
print('The country dataframe has', country_df.name.count(), 'tracks')
print('The rock dataframe has', rock_df.name.count(), 'tracks')
print('The hiphop dataframe has', hiphop_df.name.count(), 'tracks')
print('The pop dataframe has', pop_df.name.count(), 'tracks')
# Out:
# The classical dataframe has 499 tracks
# The country dataframe has 500 tracks
# The rock dataframe has 500 tracks
# The hiphop dataframe has 499 tracks
# The pop dataframe has 500 tracks

# %%
pop_df.head()
# Out:
#                                             album                artist  \
# 0  ...Baby One More Time (Digital Deluxe Version)      [Britney Spears]
# 1  reputation (Big Machine Radio Release Special)        [Taylor Swift]
# 2                         Oops!... I Did It Again      [Britney Spears]
# 3           Christina Aguilera (Expanded Edition)  [Christina Aguilera]
# 4                                           Spice         [Spice Girls]
#
#    explicit                      id                      name  popularity  \
# 0     False  3MjUtNVVq3C8Fn0MP3zhXa     ...Baby One More Time          77
# 1     False  1JbR9RDP3ogVNEWFgNXAjh  Look What You Made Me Do          77
# 2     False  6naxalmIoLFWR0siv8dnQQ    Oops!...I Did It Again          77
# 3     False  11mwFrKvLXCbcVGNxffGyP         Genie in a Bottle          73
# 4     False  1Je1IMUlBXcx1Fz0WE7oPT                   Wannabe          82
#
#    acousticness                                       analysis_url  \
# 0         0.202  https://api.spotify.com/v1/audio-analysis/3MjU...
# 1         0.204  https://api.spotify.com/v1/audio-analysis/1JbR...
# 2         0.300  https://api.spotify.com/v1/audio-analysis/6nax...
# 3         0.210  https://api.spotify.com/v1/audio-analysis/11mw...
# 4         0.101  https://api.spotify.com/v1/audio-analysis/1Je1...
#
#    danceability  duration_ms      ...       mode  speechiness    tempo  \
# 0         0.759       211067      ...          0       0.0307   92.960
# 1         0.766       211853      ...          0       0.1230  128.070
# 2         0.751       211160      ...          0       0.0437   95.053
# 3         0.627       217573      ...          1       0.1620  175.815
# 4         0.768       173027      ...          1       0.0324  110.008
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/3MjUtNVVq3C8...
# 1               4  https://api.spotify.com/v1/tracks/1JbR9RDP3ogV...
# 2               4  https://api.spotify.com/v1/tracks/6naxalmIoLFW...
# 3               4  https://api.spotify.com/v1/tracks/11mwFrKvLXCb...
# 4               4  https://api.spotify.com/v1/tracks/1Je1IMUlBXcx...
#
#              type                                   uri  valence  \
# 0  audio_features  spotify:track:3MjUtNVVq3C8Fn0MP3zhXa    0.907
# 1  audio_features  spotify:track:1JbR9RDP3ogVNEWFgNXAjh    0.506
# 2  audio_features  spotify:track:6naxalmIoLFWR0siv8dnQQ    0.894
# 3  audio_features  spotify:track:11mwFrKvLXCbcVGNxffGyP    0.912
# 4  audio_features  spotify:track:1Je1IMUlBXcx1Fz0WE7oPT    0.891
#
#    playlist_name playlist_desc
# 0            pop     Pop songs
# 1            pop     Pop songs
# 2            pop     Pop songs
# 3            pop     Pop songs
# 4            pop     Pop songs
#
# [5 rows x 25 columns]

# %%
hiphop_df.head()
# Out:
#                              album                           artist  explicit  \
# 0                   Let's Get Free                      [Dead Prez]      True
# 1                          Bij Mij               [Bizzey, Josylvio]      True
# 2                        Cali Love                           [Tyga]      True
# 3                  Groove Sessions  [Chinese Man, Bionic Man Sound]     False
# 4  good kid, m.A.A.d city (Deluxe)        [Kendrick Lamar, Dr. Dre]      True
#
#                        id                                          name  \
# 0  2HoDr1yVksl19omOhc1zWy                                       Hip Hop
# 1  2MIXE427LrQuEjhQecinAi                                       Bij Mij
# 2  6ievPGLJVOHtizroTE9VfT                                     Cali Love
# 3  0phAx12SI8oWN1AmhyceSQ                             Washington Square
# 4  5UHjWOJA6MDl1g3x2HC68V  The Recipe (Black Hippy Remix) - Bonus Track
#
#    popularity  acousticness  \
# 0          64      0.000633
# 1          47      0.021000
# 2          40      0.005850
# 3          50      0.380000
# 4          54      0.000588
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/2HoD...         0.725
# 1  https://api.spotify.com/v1/audio-analysis/2MIX...         0.756
# 2  https://api.spotify.com/v1/audio-analysis/6iev...         0.454
# 3  https://api.spotify.com/v1/audio-analysis/0phA...         0.676
# 4  https://api.spotify.com/v1/audio-analysis/5UHj...         0.723
#
#    duration_ms      ...        mode  speechiness    tempo  time_signature  \
# 0       214067      ...           1       0.3240   77.161               4
# 1       202154      ...           1       0.1500  113.125               4
# 2       229147      ...           0       0.2880  178.117               4
# 3       250600      ...           0       0.0845   89.041               4
# 4       262920      ...           0       0.1480  131.051               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/2HoDr1yVksl1...  audio_features
# 1  https://api.spotify.com/v1/tracks/2MIXE427LrQu...  audio_features
# 2  https://api.spotify.com/v1/tracks/6ievPGLJVOHt...  audio_features
# 3  https://api.spotify.com/v1/tracks/0phAx12SI8oW...  audio_features
# 4  https://api.spotify.com/v1/tracks/5UHjWOJA6MDl...  audio_features
#
#                                     uri  valence  playlist_name  playlist_desc
# 0  spotify:track:2HoDr1yVksl19omOhc1zWy    0.219         hiphop  Hip hop songs
# 1  spotify:track:2MIXE427LrQuEjhQecinAi    0.313         hiphop  Hip hop songs
# 2  spotify:track:6ievPGLJVOHtizroTE9VfT    0.520         hiphop  Hip hop songs
# 3  spotify:track:0phAx12SI8oWN1AmhyceSQ    0.758         hiphop  Hip hop songs
# 4  spotify:track:5UHjWOJA6MDl1g3x2HC68V    0.628         hiphop  Hip hop songs
#
# [5 rows x 25 columns]

# %%
rock_df.head()
# Out:
#                               album              artist  explicit  \
# 0                     Back In Black             [AC/DC]     False
# 1              Use Your Illusion II     [Guns N' Roses]     False
# 2                           Meteora       [Linkin Park]     False
# 3                          Toxicity  [System Of A Down]     False
# 4  Led Zeppelin IV (Deluxe Edition)      [Led Zeppelin]     False
#
#                        id                             name  popularity  \
# 0  08mG3Y1vljYA6bvDt4Wqkj                    Back In Black          83
# 1  4JiEyzf0Md7KEFFGWDDdCr        Knockin' On Heaven's Door          77
# 2  2nLtzopw4rPReszdYBJU6h                             Numb          82
# 3  2DlHlPMa4M17kufBvI2lEN                       Chop Suey!          81
# 4  5CQ30WqJwcep0pYcV4AMNc  Stairway to Heaven - Remastered          79
#
#    acousticness                                       analysis_url  \
# 0      0.011000  https://api.spotify.com/v1/audio-analysis/08mG...
# 1      0.021100  https://api.spotify.com/v1/audio-analysis/4JiE...
# 2      0.004600  https://api.spotify.com/v1/audio-analysis/2nLt...
# 3      0.000278  https://api.spotify.com/v1/audio-analysis/2DlH...
# 4      0.580000  https://api.spotify.com/v1/audio-analysis/5CQ3...
#
#    danceability  duration_ms      ...       mode  speechiness    tempo  \
# 0         0.310       255493      ...          1       0.0470  188.386
# 1         0.496       336000      ...          1       0.0415  132.410
# 2         0.496       185587      ...          1       0.0381  110.018
# 3         0.419       210240      ...          0       0.1200  127.288
# 4         0.338       482830      ...          0       0.0339   82.433
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/08mG3Y1vljYA...
# 1               4  https://api.spotify.com/v1/tracks/4JiEyzf0Md7K...
# 2               4  https://api.spotify.com/v1/tracks/2nLtzopw4rPR...
# 3               4  https://api.spotify.com/v1/tracks/2DlHlPMa4M17...
# 4               4  https://api.spotify.com/v1/tracks/5CQ30WqJwcep...
#
#              type                                   uri  valence  \
# 0  audio_features  spotify:track:08mG3Y1vljYA6bvDt4Wqkj    0.763
# 1  audio_features  spotify:track:4JiEyzf0Md7KEFFGWDDdCr    0.378
# 2  audio_features  spotify:track:2nLtzopw4rPReszdYBJU6h    0.243
# 3  audio_features  spotify:track:2DlHlPMa4M17kufBvI2lEN    0.286
# 4  audio_features  spotify:track:5CQ30WqJwcep0pYcV4AMNc    0.197
#
#    playlist_name playlist_desc
# 0           rock
# 1           rock
# 2           rock
# 3           rock
# 4           rock
#
# [5 rows x 25 columns]

# %%
country_df.head()
# Out:
#                 album            artist  explicit                      id  \
# 0      True Believers   [Darius Rucker]     False  3xdjjKMcMOFgo1eQrfbogM
# 1      Crash My Party      [Luke Bryan]     False  03fT3OHB9KyMtGMt2zwqCT
# 2      The Foundation  [Zac Brown Band]     False  4dGJf1SER1T6ooX46vwzRB
# 3          Montevallo        [Sam Hunt]     False  1TwLKNsCnhi1HxbIi4bAW0
# 4  This One's for You      [Luke Combs]     False  6xHI9KjUjYT0FPtGO8Mxa1
#
#             name  popularity  acousticness  \
# 0    Wagon Wheel          74        0.4560
# 1  Play It Again          74        0.0832
# 2  Chicken Fried          76        0.6450
# 3    House Party          72        0.1130
# 4      Hurricane          79        0.0153
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/3xdj...         0.529
# 1  https://api.spotify.com/v1/audio-analysis/03fT...         0.510
# 2  https://api.spotify.com/v1/audio-analysis/4dGJ...         0.566
# 3  https://api.spotify.com/v1/audio-analysis/1TwL...         0.747
# 4  https://api.spotify.com/v1/audio-analysis/6xHI...         0.464
#
#    duration_ms      ...        mode  speechiness    tempo  time_signature  \
# 0       298400      ...           1       0.0306  148.102               4
# 1       226867      ...           1       0.0696  144.056               4
# 2       238147      ...           1       0.0417  169.864               4
# 3       190240      ...           1       0.0514  103.966               4
# 4       222533      ...           1       0.0416   75.975               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/3xdjjKMcMOFg...  audio_features
# 1  https://api.spotify.com/v1/tracks/03fT3OHB9KyM...  audio_features
# 2  https://api.spotify.com/v1/tracks/4dGJf1SER1T6...  audio_features
# 3  https://api.spotify.com/v1/tracks/1TwLKNsCnhi1...  audio_features
# 4  https://api.spotify.com/v1/tracks/6xHI9KjUjYT0...  audio_features
#
#                                     uri  valence  playlist_name  playlist_desc
# 0  spotify:track:3xdjjKMcMOFgo1eQrfbogM    0.592        country  Country songs
# 1  spotify:track:03fT3OHB9KyMtGMt2zwqCT    0.596        country  Country songs
# 2  spotify:track:4dGJf1SER1T6ooX46vwzRB    0.807        country  Country songs
# 3  spotify:track:1TwLKNsCnhi1HxbIi4bAW0    0.859        country  Country songs
# 4  spotify:track:6xHI9KjUjYT0FPtGO8Mxa1    0.516        country  Country songs
#
# [5 rows x 25 columns]

# %%
classical_df.head()
# Out:
#    index                                              album  \
# 0      0  Liszt: Scherzo and March / 3 Liebestraume / Be...
# 1      1                    Beethoven: Piano Sonatas, Vol.3
# 2      2                       Mozart: Requiem Realisations
# 3      3                             Tchaikovsky: Swan Lake
# 4      4          Dvořák: Serenade for Strings, Czech Suite
#
#                                               artist  explicit  \
# 0                          [Franz Liszt, Jenő Jandó]     False
# 1                 [Ludwig van Beethoven, Paul Lewis]     False
# 2  [Wolfgang Amadeus Mozart, Academy of Ancient M...     False
# 3  [Pyotr Ilyich Tchaikovsky, André Previn, Londo...     False
# 4  [Antonín Dvořák, Prague Chamber Orchestra, Pet...     False
#
#                        id                                               name  \
# 0  6GzMz3s0K1YKwRVI36CgRx  Liebestraume, S541/R211 : No. 3: Nocturne in A...
# 1  3DNRdudZ2SstnDCVKFdXxG  Sonata No. 14 "Moonlight" in C-Sharp Minor", O...
# 2  3oHSL6pt9LpNrQZuQGu9wL                         Requiem, K. 626: Lacrimosa
# 3  2xizRhme7pYeITbH1NLLGt  Tchaikovsky: Swan Lake, Op. 20, Act 2: No. 10,...
# 4  3sAYxq1986j3ydqLv6jwUJ  Serenade for Strings in E Major, Op. 22, B. 52...
#
#    popularity  acousticness  \
# 0          63         0.991
# 1          68         0.995
# 2          65         0.944
# 3          62         0.910
# 4          57         0.755
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/6GzM...         0.343
# 1  https://api.spotify.com/v1/audio-analysis/3DNR...         0.184
# 2  https://api.spotify.com/v1/audio-analysis/3oHS...         0.162
# 3  https://api.spotify.com/v1/audio-analysis/2xiz...         0.109
# 4  https://api.spotify.com/v1/audio-analysis/3sAY...         0.000
#
#          ...         mode  speechiness    tempo  time_signature  \
# 0        ...            1       0.0406   60.228               3
# 1        ...            0       0.0432  170.612               3
# 2        ...            0       0.0354  132.047               3
# 3        ...            0       0.0382   86.554               4
# 4        ...            1       0.0000    0.000               0
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/6GzMz3s0K1YK...  audio_features
# 1  https://api.spotify.com/v1/tracks/3DNRdudZ2Sst...  audio_features
# 2  https://api.spotify.com/v1/tracks/3oHSL6pt9LpN...  audio_features
# 3  https://api.spotify.com/v1/tracks/2xizRhme7pYe...  audio_features
# 4  https://api.spotify.com/v1/tracks/3sAYxq1986j3...  audio_features
#
#                                     uri  valence  playlist_name  \
# 0  spotify:track:6GzMz3s0K1YKwRVI36CgRx   0.0378      classical
# 1  spotify:track:3DNRdudZ2SstnDCVKFdXxG   0.1510      classical
# 2  spotify:track:3oHSL6pt9LpNrQZuQGu9wL   0.0413      classical
# 3  spotify:track:2xizRhme7pYeITbH1NLLGt   0.0692      classical
# 4  spotify:track:3sAYxq1986j3ydqLv6jwUJ   0.0000      classical
#
#       playlist_desc
# 0  Classical songs.
# 1  Classical songs.
# 2  Classical songs.
# 3  Classical songs.
# 4  Classical songs.
#
# [5 rows x 26 columns]

# %%
# combine the playlists into one df
dfs = [classical_df.drop_duplicates('id'), 
       country_df.drop_duplicates('id'), 
       rock_df.drop_duplicates('id'), 
       hiphop_df.drop_duplicates('id'), 
       pop_df.drop_duplicates('id')]

df = pd.concat(dfs, sort=True).reset_index().drop_duplicates('id')
df.playlist_name =  df.playlist_name.astype('category')
# convert categories into numbers in order to plot
df['label_num'] = df.playlist_name.cat.codes

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Re-write section overview...
#
# Some questions that I will be asking are:
#
# * Are there features or parameters that can differentiate the genres?

# %% [markdown]
# ### Look at the different features comparing the two different playlists
#
# This section takes a look at comparing different playlists with each other in regards to their features. The features chosen are ones that have values and easily comparable in a swarm plot and its complementary violin plot; both look at the distribution of the values. These features are: acousticness, danceability, energy, instrumentalness, liveness, loudness, tempo, speechiness and valence. These features were measured/evaluated by Spotify.
#
# #### Definitions of the features (https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/)
#
# acousticness:	A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# danceability:	Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# energy:	Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# instrumentalness:  Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# liveness:	Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# loudness:	The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#
# speechiness: 	Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# tempo: 	The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# valence:	A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
# Create feature plots
title = 'Feature Plots'
fig = plt.figure(figsize=(17,56))        
fig.suptitle(title, fontsize=40, y=.89)
    
k = 1
features_orig = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 
                'loudness', 'speechiness', 'valence', 'tempo']

for feature in features_orig:
            
    plt.subplot(9,1,k)
    sns.violinplot(x="playlist_name", y=feature, data=df, inner=None)
    sns.swarmplot(x="playlist_name", y=feature, data=df,
              color="white", edgecolor="gray", alpha=0.75)
    plt.ylabel(feature.title(), fontsize=18)
    plt.xlabel('')
            
    k = k+1
    
plt.show()

# %% [markdown]
# Talk a little about the graphs...

# %% [markdown]
# ### Inferential Statistics
#
# Correlation
#
# * –1 A perfect downhill (negative) linear relationship
#
# * –0.70 A strong downhill (negative) linear relationship
#
# * –0.50 A moderate downhill (negative) relationship
#
# * –0.30 A weak downhill (negative) linear relationship
#
# * 0. No linear relationship
#
# * +0.30 A weak uphill (positive) linear relationship
#
# * +0.50 A moderate uphill (positive) relationship
#
# * +0.70 A strong uphill (positive) linear relationship
#
# * 1 A perfect uphill (positive) linear relationship

# %%
# correlation matrix

corr_matrix = df[features_orig].corr()
corr_matrix.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col0 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col1 {
#             background-color:  #fef6fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col2 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col3 {
#             background-color:  #04598c;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col4 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col5 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col6 {
#             background-color:  #fbf4f9;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col7 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow0_col8 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col0 {
#             background-color:  #e2dfee;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col1 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col2 {
#             background-color:  #1278b4;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col3 {
#             background-color:  #eee9f3;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col4 {
#             background-color:  #dddbec;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col5 {
#             background-color:  #0a73b2;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col6 {
#             background-color:  #6da6cd;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col7 {
#             background-color:  #0569a4;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow1_col8 {
#             background-color:  #ede8f3;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col0 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col1 {
#             background-color:  #2786bb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col2 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col3 {
#             background-color:  #fdf5fa;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col4 {
#             background-color:  #adc1dd;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col5 {
#             background-color:  #034973;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col6 {
#             background-color:  #c9cee4;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col7 {
#             background-color:  #056ead;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow2_col8 {
#             background-color:  #9ab8d8;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col0 {
#             background-color:  #045788;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col1 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col2 {
#             background-color:  #f4edf6;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col3 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col4 {
#             background-color:  #fbf3f9;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col5 {
#             background-color:  #fbf4f9;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col6 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col7 {
#             background-color:  #fef6fa;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow3_col8 {
#             background-color:  #fdf5fa;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col0 {
#             background-color:  #a9bfdc;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col1 {
#             background-color:  #a1bbda;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col2 {
#             background-color:  #4897c4;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col3 {
#             background-color:  #b0c2de;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col4 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col5 {
#             background-color:  #62a2cb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col6 {
#             background-color:  #c1cae2;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col7 {
#             background-color:  #8bb2d4;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow4_col8 {
#             background-color:  #d7d6e9;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col0 {
#             background-color:  #faf3f9;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col1 {
#             background-color:  #197db7;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col2 {
#             background-color:  #034871;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col3 {
#             background-color:  #fff7fb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col4 {
#             background-color:  #c0c9e2;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col5 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col6 {
#             background-color:  #d0d1e6;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col7 {
#             background-color:  #0c74b2;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow5_col8 {
#             background-color:  #a1bbda;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col0 {
#             background-color:  #a9bfdc;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col1 {
#             background-color:  #3790c0;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col2 {
#             background-color:  #65a3cb;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col3 {
#             background-color:  #bcc7e1;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col4 {
#             background-color:  #c8cde4;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col5 {
#             background-color:  #75a9cf;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col6 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col7 {
#             background-color:  #6fa7ce;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow6_col8 {
#             background-color:  #ede7f2;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col0 {
#             background-color:  #e4e1ef;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col1 {
#             background-color:  #0569a5;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col2 {
#             background-color:  #0567a2;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col3 {
#             background-color:  #ede8f3;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col4 {
#             background-color:  #cccfe5;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col5 {
#             background-color:  #056dab;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col6 {
#             background-color:  #a9bfdc;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col7 {
#             background-color:  #023858;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow7_col8 {
#             background-color:  #b9c6e0;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow8_col0 {
#             background-color:  #b0c2de;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow8_col1 {
#             background-color:  #bcc7e1;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow8_col2 {
#             background-color:  #3d93c2;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow8_col3 {
#             background-color:  #b9c6e0;
#         }    #T_4f091c02_4394_11e9_aa03_e09d31d604abrow8_col4 {
#             bac

# %% [markdown]
# Acousticness, energy, instrumentalness, and loudness have strong linear relationships with each other. They may be able to be combined somehow... or should I just drop 3 of them? Choose the one that is the least correlative with the other features?
#
# acousticness:      |-.55, -.18, -.18, -.56, -.21| =  1.68
# energy:            |+.47, +.23, +.11, +.62, -.07| =  1.50
# instrumnentalness: |-.56, -.15, -.21, -.55, -.19| =  1.68
# loudness:          |+.52, +.16, +.09, +.58, -.06| =  1.41
#
# Looking at the distributions, energy seems to have the best?

# %%
features_cleaned = ['danceability', 'acousticness','liveness', 'energy', 'speechiness', 'valence', 'tempo']

# %% [markdown]
# ### PCA

# %% [markdown]
# Talk about PCA and why it is relevant

# %%
X = df[features_orig]
y = df['playlist_name']

scaler=StandardScaler()
pca=PCA()

pipeline=make_pipeline(scaler, pca)

pca_features=pipeline.fit_transform(X)

# get the samples for the PCA components
xs=pca_features[:,0]
ys=pca_features[:,1]

df_pca = pd.DataFrame({'track':df['name'],
                       'artist':df['artist'],
                       'id':df['id'], 
                       'label':df['playlist_name'], 
                       'x':xs,'y':ys})

df_pca.head()
# Out:
#                                                track  \
# 0  Liebestraume, S541/R211 : No. 3: Nocturne in A...
# 1  Sonata No. 14 "Moonlight" in C-Sharp Minor", O...
# 2                         Requiem, K. 626: Lacrimosa
# 3  Tchaikovsky: Swan Lake, Op. 20, Act 2: No. 10,...
# 4  Serenade for Strings in E Major, Op. 22, B. 52...
#
#                                               artist                      id  \
# 0                          [Franz Liszt, Jenő Jandó]  6GzMz3s0K1YKwRVI36CgRx
# 1                 [Ludwig van Beethoven, Paul Lewis]  3DNRdudZ2SstnDCVKFdXxG
# 2  [Wolfgang Amadeus Mozart, Academy of Ancient M...  3oHSL6pt9LpNrQZuQGu9wL
# 3  [Pyotr Ilyich Tchaikovsky, André Previn, Londo...  2xizRhme7pYeITbH1NLLGt
# 4  [Antonín Dvořák, Prague Chamber Orchestra, Pet...  3sAYxq1986j3ydqLv6jwUJ
#
#        label         x         y
# 0  classical  4.952605  1.037234
# 1  classical  5.215453 -1.053256
# 2  classical  4.647147 -0.857539
# 3  classical  4.534470 -0.249153
# 4  classical  5.037952  0.927779

# %%
fig = plt.figure(figsize=(15,5)) 

plt.subplot(1,2,1)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')

# Plot the explained variances
plt.subplot(1,2,2)
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %% [markdown]
# Make some observations about the variance plots...

# %%
pd.DataFrame(pipeline.named_steps['pca'].components_)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.425970 -0.337313 -0.427913  0.406291 -0.113744 -0.422367 -0.137819
# 1  0.097023  0.435944 -0.191635  0.034130  0.000214 -0.174251  0.614263
# 2  0.025921 -0.195495  0.023555  0.058718  0.927537 -0.062078  0.258613
# 3  0.116687  0.041331 -0.136747  0.061604 -0.241934 -0.150410  0.547689
# 4 -0.264197 -0.313809  0.124843 -0.281961 -0.212722  0.147460  0.405175
# 5 -0.066503 -0.452960  0.435555  0.601132 -0.140987  0.169758  0.246776
# 6 -0.150789  0.566440  0.095808  0.597867  0.047810  0.231929 -0.074382
# 7 -0.728806 -0.001742  0.012600  0.103511 -0.007339 -0.670523 -0.072937
# 8  0.408325  0.178157  0.739107 -0.132283 -0.027177 -0.459142 -0.030414
#
#           7         8
# 0 -0.362286 -0.122520
# 1  0.138209 -0.579539
# 2 -0.107427  0.120449
# 3  0.117580  0.753152
# 4 -0.700725 -0.120246
# 5  0.314872 -0.174926
# 6 -0.454344  0.147467
# 7  0.052462  0.015415
# 8 -0.157929  0.018325

# %%
# plot a scatterplot without labels
fig = plt.figure(figsize=(12,8)) 
plt.scatter(pca_features[:, 0], pca_features[:, 1],
            edgecolor='none')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('PCA without Labels', fontsize=20)
plt.show()

# %% [markdown]
# Observations
# Two distinct populations/blobs.

# %%
# convert categories into numbers in order to plot
df_pca['label_num'] = df_pca.label.cat.codes

# %%
c_map=ListedColormap(colors=['darkblue','darkorange','darkgreen','darkred','purple'])

# %%
# plot scatterplot of pca with labels
fig = plt.figure(figsize=(12,8))  
plt.scatter(pca_features[:, 0], pca_features[:, 1],
            c=df_pca.label_num, edgecolor='none', alpha=0.5,
            cmap=c_map)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
cbar=plt.colorbar(ticks=[0.4,1.2,2.0,2.8,3.6])
cbar.ax.set_yticklabels(['Classical','Country','HipHop','Pop','Rock'])
plt.title('PCA with Labels', fontsize=20)
plt.show()

# %% [markdown]
# Make some observations...
#
# Classical seems to be very different from the other genres based on the features as its population is very discernable.

# %% [markdown]
# ### Conclusions
#
# To re-write...

# %% [markdown]
# ## Modeling

# %% [markdown]
# Remark on benchmarks and evaluation criteria...

# %% [markdown]
# #### Logistic Regression

# %%
X = df[features_orig]
X_cleaned = df[features_cleaned]
y = df['playlist_name']

# preprocessing steps
scaler = StandardScaler()
pca = PCA()

# model selection
model = LogisticRegression(solver='lbfgs')

# create pipeline
pipe = make_pipeline(scaler, pca, model)

# train_test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# tuning hyperparameters
Cs = [0.01, 0.1, 1, 10, 100]
n_components = [2, 4, 6, 8]

pipe_cv = GridSearchCV(pipe, dict(pca__n_components=n_components, logisticregression__C=Cs), cv=5)

pipe_cv.fit(X_train, y_train)

y_pred = pipe_cv.predict(X_test)

# Compute and print metrics
print('The optimal parameters from training:', pipe_cv.best_params_)
print('The best score on the training data:', pipe_cv.best_score_)

print("\nAccuracy on the test set: {}\n".format(pipe_cv.score(X_test, y_test)))
print(classification_report(y_test, y_pred))
# Out:
# The optimal parameters from training: {'logisticregression__C': 10, 'pca__n_components': 8}
# The best score on the training data: 0.7869727709556861
#
# Accuracy on the test set: 0.816
#
#               precision    recall  f1-score   support
#
#    classical       0.98      0.99      0.99       125
#      country       0.68      0.72      0.70       125
#       hiphop       0.93      0.96      0.94       125
#          pop       0.69      0.54      0.61       125
#         rock       0.77      0.86      0.82       125
#
#    micro avg       0.82      0.82      0.82       625
#    macro avg       0.81      0.82      0.81       625
# weighted avg       0.81      0.82      0.81       625

# %%
# create confusion matrix
row_labels = ['classical', 'country', 'hiphop', 'pop', 'rock', 'total_pred']
col_labels = ['classical_pred', 'country_pred', 'hiphop_pred', 'pop_pred', 'rock_pred', 'total']

mat=confusion_matrix(y_test, y_pred)
mat=np.vstack([mat,np.sum(mat,axis=0)])
h=np.reshape(np.sum(mat,axis=1),(-1,1))
mat=np.hstack([mat,h])

pd.DataFrame(mat, index=row_labels, columns=col_labels)
# Out:
#             classical_pred  country_pred  hiphop_pred  pop_pred  rock_pred  \
# classical              124             1            0         0          0
# country                  0            90            1        20         14
# hiphop                   0             0          120         5          0
# pop                      1            31            7        68         18
# rock                     1            10            1         5        108
# total_pred             126           132          129        98        140
#
#             total
# classical     125
# country       125
# hiphop        125
# pop           125
# rock          125
# total_pred    625

# %%
# Create ROC curves
y = df['label_num']

# Binarize the output
y = label_binarize(y, classes=[0, 1, 2, 3, 4])
n_classes = y.shape[1]

# preprocessing steps
scaler = StandardScaler()
pca = PCA()

# model selection
model = LogisticRegression(solver='lbfgs', C=10)

# create pipeline
pipe = make_pipeline(scaler, pca, model)

# shuffle and split training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,
                                                    random_state=42)

# Learn to predict each class against the other
classifier = OneVsRestClassifier(pipe)
y_score = classifier.fit(X_train, y_train).decision_function(X_test)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
class_labels=['Classical','Country','Hiphop','Pop','Rock']

# Plot all ROC curves
plt.figure(figsize=(12,8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['darkblue', 'darkorange', 'darkgreen', 'darkred', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of {0} (area = {1:0.2f})'
             ''.format(class_labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves', fontsize=20)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Observations:
# Classical and hiphop are the two genres that have highest accuracy.

# %% [markdown]
# ### Naive Bayes Classifier

# %%
X = df[features_orig]
X_cleaned = df[features_cleaned]
y = df['playlist_name']

# preprocessing steps
scaler = StandardScaler()
pca = PCA()

# model selection
model = GaussianNB()

# create pipeline
pipe = make_pipeline(scaler, pca, model)

# train_test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# tuning hyperparameters
n_components = [2, 4, 6, 8]

pipe_cv = GridSearchCV(pipe, dict(pca__n_components=n_components), cv=5)

pipe_cv.fit(X_train, y_train)

y_pred = pipe_cv.predict(X_test)

# Compute and print metrics
print("Accuracy: {}\n".format(pipe_cv.score(X_test, y_test)))
print(classification_report(y_test, y_pred))
print(pipe_cv.best_params_)
# Out:
# Accuracy: 0.768
#
#               precision    recall  f1-score   support
#
#    classical       0.95      1.00      0.98       100
#      country       0.56      0.58      0.57       100
#       hiphop       0.95      0.91      0.93       100
#          pop       0.59      0.60      0.59       100
#         rock       0.81      0.75      0.78       100
#
#    micro avg       0.77      0.77      0.77       500
#    macro avg       0.77      0.77      0.77       500
# weighted avg       0.77      0.77      0.77       500
#
# {'pca__n_components': 8}

# %%
# create confusion matrix
mat=confusion_matrix(y_test, y_pred)
mat=np.vstack([mat,np.sum(mat,axis=0)])
h=np.reshape(np.sum(mat,axis=1),(-1,1))
mat=np.hstack([mat,h])

pd.DataFrame(mat, index=row_labels, columns=col_labels)
# Out:
#             classical_pred  country_pred  hiphop_pred  pop_pred  rock_pred  \
# classical               99             0            1         0          0
# country                  2            56            0        30         12
# hiphop                   0             2           91         5          2
# pop                      2            19            9        54         16
# rock                     0            13            2         6         79
# total_pred             103            90          103        95        109
#
#             total
# classical     100
# country       100
# hiphop        100
# pop           100
# rock          100
# total_pred    500

# %%
# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
class_labels=['Classical','Country','Hiphop','Pop','Rock']

# Plot all ROC curves
plt.figure(figsize=(12,8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['darkblue', 'darkorange', 'darkgreen', 'darkred', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of {0} (area = {1:0.2f})'
             ''.format(class_labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves', fontsize=20)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Conclusions
#
#
# ### Future Work
#
# Employ deep learning or other machine learning techniques.
# Integrate more musical genres, e.g. EDM, jazz, funk, etc.
# Get more data.
