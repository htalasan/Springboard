# %% [markdown]
# # Capstone Project 1: TBD

# %% [markdown]
# ## Overview

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import helper

# %%
# Token needs to be generated everytime; will expire after a while...
token = "BQBxfgUprtqSPS-d_9gbmYuhqkAIcPUcfjJJjAsEQ__8bXqGSTu7_wIDcXoz7Dve93eJUM4PGwvTVc3LY8R53mBNyaQXN8OgT0cqxhypZuL5qaHTwfAzYpaSdrqykPMqeNXyaFterkeFZYrLh7tSfqgrjt8l2ihHS-niuGvoy0GCL3-Toe42jP6dzPyHuyTF4z4t9S70FODspMA4-1RJwl-IQhArR248XjswBNv3eVeDOL2RiDd2WX-7hoKME7fz5GX191YFt9kULvKF-GY"

# %%
# created playlist to use for example
# playlist_id = '29rqX3FuqPWpoIRfrGG5Lp'

# happy playlist from spotify for example
playlist_id = '37i9dQZF1DXdPec7aLTmlC'

# %% [markdown]
# ## Data Wrangling

# %%
pl_tracks = helper.get_playlist_tracks_info(playlist_id, token)

# %%
df_track_info = pd.DataFrame.from_dict(pl_tracks).set_index('id')

# %%
df
# Out:
#                                                                     album  \
# id
# 0aersVHlGGXcHeRvHtuaSt                                             Matter
# 6gxZLe2tUdy1U51aql0mfR                                 Bad Self Portraits
# 3cAeMlAUiqsdqNuauVk0Xy                                        Gut Feeling
# 7yuUGBXakKjMjQnQssIP4I                          Must've Been (feat. DRAM)
# 7xdPwAhj4mMqDaNxvNoYnV                                          Bee-Sting
# 2FVm4ADgYRIQWlpYKDPdl9       Winnebago (feat. Quinn XCII & Daniel Wilson)
# 1hJ6x0VhpIlrrjnbqKHtfn                              Yesterday Was Forever
# 0CZ8lquoTX2Dkg7Ak2inwA                                               1950
# 7zkDEBSxkcBVsStS4qBFpK                           Wolfgang Amadeus Phoenix
# 6wvlEKW2qxucJSBXYpMV2P                              TOOTIMETOOTIMETOOTIME
# 1tNJrcVe6gwLEiZCtprs1u                       Don't Forget About Me, Demos
# 33A96oxloN7ERm1Bmz1oSs                                      Young Romance
# 5WsjSKEBcZGVjpn3liGgzu                                              Kiddo
# 6qX4gWRXTRPIrEfNuNaYye                                           For Ever
# 0D4yVl9Pn45xW2s63MFCmT             It's Not Living (If It's Not With You)
# 6Hmj7SrLRbreLVfVS7mV1S                                            Funeral
# 3o8bovLXjsxsFBTXajm1VA                                      Middle Finger
# 5Yfq9uugLFchtFymQQWxgt                                     Dirty Computer
# 7iMDaY1LnASwCk2uUpMtii                                         On The Rvn
# 39YLC6osLe9btq1vpsDglx                                      Party For One
# 4o6BgsqLIBViaGVbx5rbRk                                             Voices
# 41kE0bBBpwPUZEZKxSIROh                                         Old School
# 7yq4Qj7cqayVTp3FF9CWbm                               Dream Your Life Away
# 5q5gzmbBS5yQzos2BvVr1t                                    Nights With You
# 5uzNa0SBGOe5pPnstWHMCt                        Too Rye Ay (Deluxe Edition)
# 6rigRPkg6kRjmPXSm7X9L9                                       Pumpin Blood
# 76EeScTnI2sCjDY0SfEoSb                                    TALKING IS HARD
# 6oA7NzN7FgmXv7l7Y638HL                                            No More
# 1etiUDkISHELzQGMY79ryt                              Quarter Past Midnight
# 0JRNPoITcFcNSTRErs8moc           Everybody’s Heart Is Broken Now (Deluxe)
# 1W2ox3KxfTEQfO5NdOaK7E                                             Contra
# 15ya59dZ8yGeIfZARiYDjd                      Lungs (International Version)
# 2Pc689kt3UUV2QGddLubTA                                          Conqueror
# 1jJci4qxiYcOHhQR247rEU                               Oracular Spectacular
# 6QgjcU0zLnzq5OrUoSZ3OK                                          Woodstock
# 5WoaF1B5XIEnWfmb5NZikf                                      War & Leisure
# 43cFjTTCD9Cni4aSL0sORz                        Playinwitme (feat. Kehlani)
# 5g6QHlE01E69wL99ny45x3                                    The Lion's Roar
# 2PjqwF7kqqazmlXcqUtdR0                                            t-shirt
# 542Xd5qDeLBvgXZXhfW7LE                      Obsession (feat. Jon Bellion)
# 5yjOhc3JKrznGouRHMagoJ                                              Waves
# 5c0aiERRxHjbvu5tQ9jwAE                                    Wearing Nothing
# 7kzKAuUzOITUauHAhoMoxA                                         Is This It
# 5TIwTmk9MukdTu9mOpraCy           Everybody’s Heart Is Broken Now (Deluxe)
# 4iCKHGl4ij4YMwFrUZLGEQ      Kill The Lights (with Nile Rodgers) [Remixes]
# 15t7OIDgCF5C6mLACqZbm5                             You Me and The Silence
# 3irNpONYOfunwlUdj3WARO                                 Don't Kill My Vibe
# 5MMu9zi4UrctTCXQqNJUCY               Feels Great (feat. Fetty Wap & CVBZ)
# 20J5QaInjzeb5Rd3HpyCrC                                             Vowels
# 3XcuLPQb1LG13ZJEEa6wUI                              Build Me Up Buttercup
# 5Ef2noaxqTAfa5gLVw05OJ                    You Come First (feat. Saweetie)
# 0SA903LGHxe4ExdRY2SqVH                                       Killer Queen
# 1So1tVk3gybvc2I0JY8K22            Out Of My Head (feat. Tove Lo and ALMA)
# 2Gy7qnDwt8Z3MNxqat4CsK   Pet Sounds (Original Mono & Stereo Mix Versions)
# 4jacsL77ZYnpInmTtUBaJW  d-d-don't don't stop the beat (Explicit Conten...
# 4Sfh35NL3BWOyIpB4toKgS                                    Scissor Sisters
# 74d9QhneUCIUvO00ev5kyX                                       Overthinking
# 1RP57IhDU2nBu8x2mjqFQi                                       Abbot Kinney
# 2kSiSU6KMxTuT7tJ8TwoIq                                     Innocence Lost
# 0H8pgTFFb4K2M4t5LKsP5H                                Heavy Rules Mixtape
#
#                                                                    artist  \
# id
# 0aersVHlGGXcHeRvHtuaSt                                        [St. Lucia]
# 6gxZLe2tUdy1U51aql0mfR                                 [Lake Street Dive]
# 3cAeMlAUiqsdqNuauVk0Xy                             [Peter Bjorn and John]
# 7yuUGBXakKjMjQnQssIP4I                                    [Chromeo, DRAM]
# 7xdPwAhj4mMqDaNxvNoYnV                                      [The Wombats]
# 2FVm4ADgYRIQWlpYKDPdl9               [Gryffin, Quinn XCII, Daniel Wilson]
# 1hJ6x0VhpIlrrjnbqKHtfn                                        [Kate Nash]
# 0CZ8lquoTX2Dkg7Ak2inwA                                    [King Princess]
# 7zkDEBSxkcBVsStS4qBFpK                                          [Phoenix]
# 6wvlEKW2qxucJSBXYpMV2P                                         [The 1975]
# 1tNJrcVe6gwLEiZCtprs1u                                     [Dominic Fike]
# 33A96oxloN7ERm1Bmz1oSs                                        [Roosevelt]
# 5WsjSKEBcZGVjpn3liGgzu                                      [Tove Styrke]
# 6qX4gWRXTRPIrEfNuNaYye                                           [Jungle]
# 0D4yVl9Pn45xW2s63MFCmT                                         [The 1975]
# 6Hmj7SrLRbreLVfVS7mV1S                                      [Arcade Fire]
# 3o8bovLXjsxsFBTXajm1VA                          [Phoebe Ryan, Quinn XCII]
# 5Yfq9uugLFchtFymQQWxgt                 [Janelle Monáe, Pharrell Williams]
# 7iMDaY1LnASwCk2uUpMtii                           [Young Thug, Elton John]
# 39YLC6osLe9btq1vpsDglx                                 [Carly Rae Jepsen]
# 4o6BgsqLIBViaGVbx5rbRk                          [Daryl Hall & John Oates]
# 41kE0bBBpwPUZEZKxSIROh                                       [Urban Cone]
# 7yq4Qj7cqayVTp3FF9CWbm                                        [Vance Joy]
# 5q5gzmbBS5yQzos2BvVr1t                                               [MØ]
# 5uzNa0SBGOe5pPnstWHMCt                           [Dexys Midnight Runners]
# 6rigRPkg6kRjmPXSm7X9L9                                           [NONONO]
# 76EeScTnI2sCjDY0SfEoSb                                    [WALK THE MOON]
# 6oA7NzN7FgmXv7l7Y638HL                                          [Olivera]
# 1etiUDkISHELzQGMY79ryt                                         [Bastille]
# 0JRNPoITcFcNSTRErs8moc                                  [Niki & The Dove]
# 1W2ox3KxfTEQfO5NdOaK7E                                  [Vampire Weekend]
# 15ya59dZ8yGeIfZARiYDjd                           [Florence + The Machine]
# 2Pc689kt3UUV2QGddLubTA                                           [AURORA]
# 1jJci4qxiYcOHhQR247rEU                                             [MGMT]
# 6QgjcU0zLnzq5OrUoSZ3OK                                [Portugal. The Man]
# 5WoaF1B5XIEnWfmb5NZikf                             [Miguel, Travis Scott]
# 43cFjTTCD9Cni4aSL0sORz                                    [KYLE, Kehlani]
# 5g6QHlE01E69wL99ny45x3                                    [First Aid Kit]
# 2PjqwF7kqqazmlXcqUtdR0                                            [gnash]
# 542Xd5qDeLBvgXZXhfW7LE                                [Vice, Jon Bellion]
# 5yjOhc3JKrznGouRHMagoJ                                   [Rachel Platten]
# 5c0aiERRxHjbvu5tQ9jwAE                                            [Dagny]
# 7kzKAuUzOITUauHAhoMoxA                                      [The Strokes]
# 5TIwTmk9MukdTu9mOpraCy                                  [Niki & The Dove]
# 4iCKHGl4ij4YMwFrUZLGEQ  [Alex Newell, Jess Glynne, DJ Cassidy, Nile Ro...
# 15t7OIDgCF5C6mLACqZbm5                                             [LOVA]
# 3irNpONYOfunwlUdj3WARO                                           [Sigrid]
# 5MMu9zi4UrctTCXQqNJUCY                     [Cheat Codes, Fetty Wap, CVBZ]
# 20J5QaInjzeb5Rd3HpyCrC                                   [Capital Cities]
# 3XcuLPQb1LG13ZJEEa6wUI                                  [The Foundations]
# 5Ef2noaxqTAfa5gLVw05OJ                               [Zak Abel, Saweetie]
# 0SA903LGHxe4ExdRY2SqVH                              [5 Seconds of Summer]
# 1So1tVk3gybvc2I0JY8K22                        [Charli XCX, Tove Lo, ALMA]
# 2Gy7qnDwt8Z3MNxqat4CsK                                   [The Beach Boys]
# 4jacsL77ZYnpInmTtUBaJW                                    [Junior Senior]
# 4Sfh35NL3BWOyIpB4toKgS                                  [Scissor Sisters]
# 74d9QhneUCIUvO00ev5kyX                                       [SHY Martin]
# 1RP57IhDU2nBu8x2mjqFQi                           [Netsky, Stargate, KYLE]
# 2kSiSU6KMxTuT7tJ8TwoIq                                      [Erik Hassle]
# 0H8pgTFFb4K2M4t5LKsP5H                                [ALMA, Tove Styrke]
#
#                                                                      name
# id
# 0aersVHlGGXcHeRvHtuaSt                                   Dancing On Glass
# 6gxZLe2tUdy1U51aql0mfR                                 You Go Down Smooth
# 3cAeMlAUiqsdqNuauVk0Xy                                        Gut Feeling
# 7yuUGBXakKjMjQnQssIP4I                          Must've Been (feat. DRAM)
# 7xdPwAhj4mMqDaNxvNoYnV                                          Bee-Sting
# 2FVm4ADgYRIQWlpYKDPdl9       Winnebago (feat. Quinn XCII & Daniel Wilson)
# 1hJ6x0VhpIlrrjnbqKHtfn                                          Body Heat
# 0CZ8lquoTX2Dkg7Ak2inwA                                               1950
# 7zkDEBSxkcBVsStS4qBFpK                                        Lisztomania
# 6wvlEKW2qxucJSBXYpMV2P                              TOOTIMETOOTIMETOOTIME
# 1tNJrcVe6gwLEiZCtprs1u                                           3 Nights
# 33A96oxloN7ERm1Bmz1oSs                                       Losing Touch
# 5WsjSKEBcZGVjpn3liGgzu                                         Number One
# 6qX4gWRXTRPIrEfNuNaYye                             Beat 54 (All Good Now)
# 0D4yVl9Pn45xW2s63MFCmT             It's Not Living (If It's Not With You)
# 6Hmj7SrLRbreLVfVS7mV1S                                            Wake Up
# 3o8bovLXjsxsFBTXajm1VA                                      Middle Finger
# 5Yfq9uugLFchtFymQQWxgt          I Got The Juice (feat. Pharrell Williams)
# 7iMDaY1LnASwCk2uUpMtii                            High (feat. Elton John)
# 39YLC6osLe9btq1vpsDglx                                      Party For One
# 4o6BgsqLIBViaGVbx5rbRk                                 You Make My Dreams
# 41kE0bBBpwPUZEZKxSIROh                                         Old School
# 7yq4Qj7cqayVTp3FF9CWbm                                            Riptide
# 5q5gzmbBS5yQzos2BvVr1t                                    Nights With You
# 5uzNa0SBGOe5pPnstWHMCt                                     Come On Eileen
# 6rigRPkg6kRjmPXSm7X9L9                                       Pumpin Blood
# 76EeScTnI2sCjDY0SfEoSb                                     Work This Body
# 6oA7NzN7FgmXv7l7Y638HL                                            No More
# 1etiUDkISHELzQGMY79ryt                              Quarter Past Midnight
# 0JRNPoITcFcNSTRErs8moc                                   You Want The Sun
# 1W2ox3KxfTEQfO5NdOaK7E                                          White Sky
# 15ya59dZ8yGeIfZARiYDjd                                  Dog Days Are Over
# 2Pc689kt3UUV2QGddLubTA                                          Conqueror
# 1jJci4qxiYcOHhQR247rEU                                               Kids
# 6QgjcU0zLnzq5OrUoSZ3OK                                      Feel It Still
# 5WoaF1B5XIEnWfmb5NZikf                    Sky Walker (feat. Travis Scott)
# 43cFjTTCD9Cni4aSL0sORz                        Playinwitme (feat. Kehlani)
# 5g6QHlE01E69wL99ny45x3                                  King of the World
# 2PjqwF7kqqazmlXcqUtdR0                                            t-shirt
# 542Xd5qDeLBvgXZXhfW7LE                      Obsession (feat. Jon Bellion)
# 5yjOhc3JKrznGouRHMagoJ                                            Shivers
# 5c0aiERRxHjbvu5tQ9jwAE                                    Wearing Nothing
# 7kzKAuUzOITUauHAhoMoxA                                          Last Nite
# 5TIwTmk9MukdTu9mOpraCy                                Play It On My Radio
# 4iCKHGl4ij4YMwFrUZLGEQ  Kill The Lights (with Nile Rodgers) - Audien R...
# 15t7OIDgCF5C6mLACqZbm5                             You Me and The Silence
# 3irNpONYOfunwlUdj3WARO                                 Don't Kill My Vibe
# 5MMu9zi4UrctTCXQqNJUCY               Feels Great (feat. Fetty Wap & CVBZ)
# 20J5QaInjzeb5Rd3HpyCrC                                             Vowels
# 3XcuLPQb1LG13ZJEEa6wUI                              Build Me Up Buttercup
# 5Ef2noaxqTAfa5gLVw05OJ                    You Come First (feat. Saweetie)
# 0SA903LGHxe4ExdRY2SqVH                                       Killer Queen
# 1So1tVk3gybvc2I0JY8K22            Out Of My Head (feat. Tove Lo and ALMA)
# 2Gy7qnDwt8Z3MNxqat4CsK                   Wouldn't It Be Nice - Stereo Mix
# 4jacsL77ZYnpInmTtUBaJW                                     Move Your Feet
# 4Sfh35NL3BWOyIpB4toKgS                                     Take Your Mama
# 74d9QhneUCIUvO00ev5kyX                               Just a Little Longer
# 1RP57IhDU2nBu8x2mjqFQi                  Big Hearts (feat. Stargate, KYLE)
# 2kSiSU6KMxTuT7tJ8TwoIq                                           No Words
# 0H8pgTFFb4K2M4t5LKsP5H                     Good Vibes (feat. Tove Styrke)

# %%
url = f"https://api.spotify.com/v1/me/playlists/"
headers = {'Authorization': f"Bearer {token}"}
r = requests.get(url, headers=headers)
parsed = json.loads(r.text)

# %% [markdown]
# ## EDA
