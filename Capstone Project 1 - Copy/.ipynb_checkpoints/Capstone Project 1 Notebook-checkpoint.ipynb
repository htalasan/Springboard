# %% [markdown]
# # Capstone Project 1: Does a song/track belong in this Spotify playlist?

# %% [markdown]
# ## Overview
#
# The main question I want to explore is **does a song/track belong in a particular playlist**? This may be done by first analyzing the particular playlist and determining a specific ‘theme’ based on the current tracks of the playlist. Then see if a particular track fits in that overarching theme. If it does, it would be recommended that the track shouldn’t be included, but if it does it is recommended to be included.
#
# The client would be any user interested in music, but specifically a user that needs to curate a playlist like a DJ. By implementing the above, this may help the user better curate a playlist for a particular sound, mood, or intangible ‘thing’ that describes the playlist by trying to recommend avoiding including a song that may not mesh well with the theme of the playlist.

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import helper

sns.set()

# %% [markdown]
# Link for token generation:
# https://developer.spotify.com/console/get-current-user-playlists/?limit=&offset=

# %%
# Token needs to be generated everytime; will expire after a while...
token = "BQBfiwFCvA-ZWBhLxIlz87rPD0wli2-QjYxVAZ6t4VudgDFkjNlGhftw8VR74LQEMVyd9kps-snAbm8sFbXsmES5I2ThTAd6aKbEhPPpLF8zWNvmD9vNwcfd8y-ftThtKVt83_ZQNXbpgubXDWHK-Qj_DZjOYQLHEnEYYTM__e510qLmUCLyFUT9tfDa_vhwLPPfjS6-fZWjD97mXU28yR8F7Vx8swnSSVqP0iPAJIKhYDRVhUb8HQwD7ogYv6IZdCyGdh_qQX6qNlRGLjI"

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# This section is primarily used for wrangling the data that can be procured through the Spotify API. Because the coding can get complex, I've decided to create a helper.py that contains python methods that are used to wrangle the data. Please see the file for the code and more information on each method to help wrangle the Spotify data.

# %%
# helper.get_playlist_list(token) # get the names of the playlists to use

# %%
# example playlists
playlist_id_happy1 = '37i9dQZF1DXdPec7aLTmlC' # Happy Hits! | 60 songs | 3m followers
playlist_id_happy2 = '37i9dQZF1DX0UrRvztWcAU' # Wake Up Happy | 70 songs | 1m followers
playlist_id_happy3 = '37i9dQZF1DX3rxVfibe1L0' # Mood Booster | 75 songs | 3m followers
playlist_id_sad1 = '4EoPt05ztUjVaujcWbUL2Z' # Sad Songs😔 | 100 songs | 500k followers
playlist_id_sad2 = '37i9dQZF1DX7qK8ma5wgG1' # Sad Songs | 60 songs | 650k followers

# %% [markdown]
# The playlists above were chosen as example 'themed' playlists because they all have a good amount of songs (> 60) and a good amount of followers. The number of followers is important since it gives some validity to the playlist that it encompasses the theme it is trying to represent.
#
# To note: There might be some overlap in songs between the similarly themed playlists.

# %%
df_happy1 = helper.get_df_from_playlist(playlist_id_happy1, token)

# %%
df_happy2 = helper.get_df_from_playlist(playlist_id_happy2, token)

# %%
df_happy3 = helper.get_df_from_playlist(playlist_id_happy3, token)

# %%
df_sad1 = helper.get_df_from_playlist(playlist_id_sad1, token)

# %%
df_sad2 = helper.get_df_from_playlist(playlist_id_sad2, token)

# %%
df_happy1.head()
# Out:
#                                            album                  artist  \
# id
# 0aersVHlGGXcHeRvHtuaSt                    Matter             [St. Lucia]
# 6gxZLe2tUdy1U51aql0mfR        Bad Self Portraits      [Lake Street Dive]
# 7zkDEBSxkcBVsStS4qBFpK  Wolfgang Amadeus Phoenix               [Phoenix]
# 7xdPwAhj4mMqDaNxvNoYnV                 Bee-Sting           [The Wombats]
# 3cAeMlAUiqsdqNuauVk0Xy               Gut Feeling  [Peter Bjorn and John]
#
#                         explicit                name  popularity  \
# id
# 0aersVHlGGXcHeRvHtuaSt     False    Dancing On Glass          60
# 6gxZLe2tUdy1U51aql0mfR     False  You Go Down Smooth          10
# 7zkDEBSxkcBVsStS4qBFpK     False         Lisztomania          65
# 7xdPwAhj4mMqDaNxvNoYnV     False           Bee-Sting          61
# 3cAeMlAUiqsdqNuauVk0Xy     False         Gut Feeling          57
#
#                         acousticness  \
# id
# 0aersVHlGGXcHeRvHtuaSt        0.0189
# 6gxZLe2tUdy1U51aql0mfR        0.0642
# 7zkDEBSxkcBVsStS4qBFpK        0.0349
# 7xdPwAhj4mMqDaNxvNoYnV        0.0457
# 3cAeMlAUiqsdqNuauVk0Xy        0.1150
#
#                                                              analysis_url  \
# id
# 0aersVHlGGXcHeRvHtuaSt  https://api.spotify.com/v1/audio-analysis/0aer...
# 6gxZLe2tUdy1U51aql0mfR  https://api.spotify.com/v1/audio-analysis/6gxZ...
# 7zkDEBSxkcBVsStS4qBFpK  https://api.spotify.com/v1/audio-analysis/7zkD...
# 7xdPwAhj4mMqDaNxvNoYnV  https://api.spotify.com/v1/audio-analysis/7xdP...
# 3cAeMlAUiqsdqNuauVk0Xy  https://api.spotify.com/v1/audio-analysis/3cAe...
#
#                         danceability  duration_ms  energy  \
# id
# 0aersVHlGGXcHeRvHtuaSt         0.564       246333   0.945
# 6gxZLe2tUdy1U51aql0mfR         0.310       209400   0.794
# 7zkDEBSxkcBVsStS4qBFpK         0.635       241547   0.786
# 7xdPwAhj4mMqDaNxvNoYnV         0.650       214433   0.866
# 3cAeMlAUiqsdqNuauVk0Xy         0.609       182538   0.804
#
#                                               ...                          \
# id                                            ...
# 0aersVHlGGXcHeRvHtuaSt                        ...
# 6gxZLe2tUdy1U51aql0mfR                        ...
# 7zkDEBSxkcBVsStS4qBFpK                        ...
# 7xdPwAhj4mMqDaNxvNoYnV                        ...
# 3cAeMlAUiqsdqNuauVk0Xy                        ...
#
#                         mode  speechiness    tempo  time_signature  \
# id
# 0aersVHlGGXcHeRvHtuaSt     1       0.0493  101.003               4
# 6gxZLe2tUdy1U51aql0mfR     1       0.0831  189.184               4
# 7zkDEBSxkcBVsStS4qBFpK     1       0.0377   97.540               4
# 7xdPwAhj4mMqDaNxvNoYnV     1       0.0343  115.001               4
# 3cAeMlAUiqsdqNuauVk0Xy     1       0.0420  131.986               4
#
#                                                                track_href  \
# id
# 0aersVHlGGXcHeRvHtuaSt  https://api.spotify.com/v1/tracks/0aersVHlGGXc...
# 6gxZLe2tUdy1U51aql0mfR  https://api.spotify.com/v1/tracks/6gxZLe2tUdy1...
# 7zkDEBSxkcBVsStS4qBFpK  https://api.spotify.com/v1/tracks/7zkDEBSxkcBV...
# 7xdPwAhj4mMqDaNxvNoYnV  https://api.spotify.com/v1/tracks/7xdPwAhj4mMq...
# 3cAeMlAUiqsdqNuauVk0Xy  https://api.spotify.com/v1/tracks/3cAeMlAUiqsd...
#
#                                   type                                   uri  \
# id
# 0aersVHlGGXcHeRvHtuaSt  audio_features  spotify:track:0aersVHlGGXcHeRvHtuaSt
# 6gxZLe2tUdy1U51aql0mfR  audio_features  spotify:track:6gxZLe2tUdy1U51aql0mfR
# 7zkDEBSxkcBVsStS4qBFpK  audio_features  spotify:track:7zkDEBSxkcBVsStS4qBFpK
# 7xdPwAhj4mMqDaNxvNoYnV  audio_features  spotify:track:7xdPwAhj4mMqDaNxvNoYnV
# 3cAeMlAUiqsdqNuauVk0Xy  audio_features  spotify:track:3cAeMlAUiqsdqNuauVk0Xy
#
#                         valence playlist_name  \
# id
# 0aersVHlGGXcHeRvHtuaSt    0.399   Happy Hits!
# 6gxZLe2tUdy1U51aql0mfR    0.284   Happy Hits!
# 7zkDEBSxkcBVsStS4qBFpK    0.305   Happy Hits!
# 7xdPwAhj4mMqDaNxvNoYnV    0.717   Happy Hits!
# 3cAeMlAUiqsdqNuauVk0Xy    0.633   Happy Hits!
#
#                                                             playlist_desc
# id
# 0aersVHlGGXcHeRvHtuaSt  Hits to boost your mood and fill you with happ...
# 6gxZLe2tUdy1U51aql0mfR  Hits to boost your mood and fill you with happ...
# 7zkDEBSxkcBVsStS4qBFpK  Hits to boost your mood and fill you with happ...
# 7xdPwAhj4mMqDaNxvNoYnV  Hits to boost your mood and fill you with happ...
# 3cAeMlAUiqsdqNuauVk0Xy  Hits to boost your mood and fill you with happ...
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Data Storytelling

# %% [markdown]
# For this part of the project, I wanted to see if two different playlists have features that separates the two. In the following case, I chose to explore 'happy' themed playlists versus 'sad' themed playlists as these two themes are opposite of each other. In that same vein, it would also be interesting to see if the same types of playlists' features are hardly separable, meaning that the feature values would be almost identical as they should be of the same theme. The playlists chosen above are playlists that consist of many followers and where the theme is obvious in the title of the playlist.
#
# Some questions that I will be asking are:
#
# * Are there features or parameters that can differentiate two differently 'themed' playlists?
# * What of similarly 'themed' playlists?

# %% [markdown]
# ### Look at the different features comparing the two different playlists
#
# This section takes a look at comparing different playlists with each other in regards to their features. The features chosen are ones that have values and easily comparable in a histogram plot. These features are: acousticness, danceability, energy, instrumentalness, liveness, loudness, tempo, speechiness and valence. These features were measured/evaluated by Spotify.
#
# #### Definitions of the features
#
# acousticness:	A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# danceability:	Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# energy:	Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# instrumentalness:  Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# liveness:	Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# loudness:	The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#
# speechiness: 	Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# tempo: 	The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# valence:	A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
def playlist_comparison_features_plots(df1, df2, title):
    """Creates plots to compare the different features (above) of two playlists"""
    label1 = df1.playlist_name[0]
    label2 = df2.playlist_name[0]
    
    fig = plt.figure(figsize=(15,15))    
    fig.suptitle(title, fontsize=40, y=.95)
    
    k = 1
    features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 
                'loudness', 'speechiness', 'valence', 'tempo']
    
    for feature in features:
        if feature=='loudness':
            bins=np.arange(-20,0,2)            
        elif feature=='tempo':
            bins=np.arange(50,250,20)
        else:
            bins = np.arange(0, 1.1, .1)
        
        plt.subplot(3,3,k)
        plt.hist(df1[feature], bins=bins, alpha=0.5, color='orange', label=label1)
        plt.hist(df2[feature], bins=bins, alpha=0.5, color='blue', label=label2)
        plt.title(feature.title())
        
        if k in [1,4,7]:
            plt.ylabel('Frequency')
        if k in [7,8,9]:
            plt.xlabel('Value')
        if k in [3,6,9]:
            plt.legend()
            
        k = k+1
    
    plt.show()

# %%
playlist_comparison_features_plots(df_happy1, df_sad2, 'Happy Vs. Sad Playlists')

# %% [markdown]
# This figure shows the comparison of two differently 'themed' playlists, specifically a happy playlist versus a sad one. According to the plots, valence, acousticness, danceability, and energy are features one can visually see that have different sample populations between the two playlists. This makes sense as one may equate happiness as full of energy and optimism while sadness envokes depression or lethargy. Also, there might be a difference in the liveness and loudness features that can be visually seen. Finally, speechiness, instrumentalness, and tempo are features that are hard to visually see any difference between the two playlists.

# %%
playlist_comparison_features_plots(df_happy1, df_happy2, 'Happy vs. Happy Playlists')

# %%
playlist_comparison_features_plots(df_sad1, df_sad2, 'Sad vs. Sad Playlists')

# %% [markdown]
# WIth the previous two figures, I compared similarly themed playlists. As you can see, there is not a lot to visually distinct the feature plots between the two chosen playlists in both of the comparisons. To note, in the 'Sad vs. Sad Playlists', one of the playlists has significantly more songs in it. However, the distributions of the values still look very similar and that's why I would classify that there there is not visual distinction between the two playlists.

# %% [markdown]
# ### Looking at the 'modes' of each playlist (major vs. minor key)

# %%
modes = []
modes.append(df_sad1['mode'].sum()/sum(df_sad1['mode'].value_counts()) * 100)
modes.append(df_sad2['mode'].sum()/sum(df_sad2['mode'].value_counts()) * 100)
modes.append(df_happy1['mode'].sum()/sum(df_happy1['mode'].value_counts()) * 100)
modes.append(df_happy2['mode'].sum()/sum(df_happy2['mode'].value_counts()) * 100)

playlists = ['Sad1', 'Sad2', 'Happy1', 'Happy2']

plt.bar(playlists, modes, color=['blue','blue','orange','orange'], alpha=0.75)
plt.ylim(0,100)
plt.xlabel('Playlist')
plt.ylabel('% of Major Key Songs')
plt.title('Major Key % in Playlists')
plt.show()

# %% [markdown]
# Initially, I thought there would be more differences in the percentage of major keys in playlists since a song with a major key usually has a more uplifting tone to it whereas a minor key has a more melancholy tone to it. Therefore, it may have been a good distinction between happy vs. sad playlists. The plot above seems to suggest that there is no difference between the happy and sad playlists with respect to the major key percentage.

# %% [markdown]
# ### Looking at the explicitness of each playlist

# %%
sad1_explicit = df_sad1['explicit'].value_counts()
sad2_explicit = df_sad2['explicit'].value_counts()
happy1_explicit = df_happy1['explicit'].value_counts()
happy2_explicit = df_happy2['explicit'].value_counts()

explicitness = []
explicitness.append(sad1_explicit[1]/(sad1_explicit[0] + sad1_explicit[1]) * 100)
explicitness.append(sad2_explicit[1]/(sad2_explicit[0] + sad2_explicit[1]) * 100)
explicitness.append(happy1_explicit[1]/(happy1_explicit[0] + sad1_explicit[1]) * 100)
explicitness.append(happy2_explicit[1]/(happy2_explicit[0] + happy2_explicit[1]) * 100)

playlists = ['Sad1', 'Sad2', 'Happy1', 'Happy2']

plt.bar(playlists, explicitness, color=['blue','blue','orange','orange'], alpha=0.75)
plt.ylim(0,20)
plt.xlabel('Playlist')
plt.ylabel('% of Explicit Songs')
plt.title('Explicitness % in Playlists')
plt.show()

# %% [markdown]
# In the figure above, it seems that there is more explicit songs in happy themed playlists than there is in sad playlists. However, this doesn't feel like a big difference so more testing and samples should be gained before any conclusions about the explicitness of playlists can be made.

# %% [markdown]
# ### Conclusions
#
# By taking a look at differently and similarly themed playlists, we can see that it is possible to differentiate between two different playlists and playlists with the same theme have similar values. However, in order to complete the objective of the project, some more questions need to be asked:
#
# * What of playlists of more questionable theme? I.e. a theme that is not easily described.
# * How many songs does it take to instantiate a theme?
# * There are features that can make a distinction between these two themes. However, that is not to say that these features would work for all themes. Is there a way to select the correct features for each theme?
#
# The following sections will hopefully answer these questions.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In this section I hope to do statitstical analysis on the features from the previous section to affirm that there is a differentiation between the two playlists. In the following analysis, I will make the following assumption that the playlists that are sad are sad and the playlists that are happy are happy. In the previous section, the visual analysis can suggest that this is appropriate as when comparing the same playlist types ended in similar looking plots. Therefore, I will combine the same playlists together and tag the songs with their respective label. This is to increase the number of samples for each of the 'themes' to compare, making for a better statistical analysis.

# %%
# functions
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n + 1) / n

    return x, y

def draw_bs_reps(data, func, size=1):
    """Draw bootstrap replicates."""

    # Initialize array of replicates: bs_replicates
    bs_replicates = np.empty(size)

    # Generate replicates
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data,func)

    return bs_replicates

def bootstrap_replicate_1d(data, func):
    return func(np.random.choice(data, size=len(data)))

def feature_p_value(data1, data2, func):
    """This gets the p value for the comparison of two features and their values"""
    
    empirical_diff = abs(np.mean(data2) - np.mean(data1))
    data_combined = data1.append(data2)
    
    # shift the mean since we are testing that the means are equal
    
    data1_shifted = data1 - func(data1) + func(data_combined)
    data2_shifted = data2 - func(data2) + func(data_combined)
    
    # create bootstrap reps for each of the populations
    
    bs_reps_1 = draw_bs_reps(data1_shifted, np.mean, 10000)
    bs_reps_2 = draw_bs_reps(data2_shifted, np.mean, 10000)
    
    difference_in_data = abs(bs_reps_2 - bs_reps_1)
    
    # find the p-value
    p = np.sum(difference_in_data >= empirical_diff)/len(difference_in_data)
    return p

# %%
# combine all the playlists and label happy and sad appropriately

df_combined_happy = df_happy1.append(df_happy2)
df_combined_happy['label'] = 'happy' 

df_combined_sad = df_sad1.append(df_sad2)
df_combined_sad['label'] = 'sad'

df_combined = df_combined_sad.append(df_combined_happy)

# %% [markdown]
# Before doing the actual numbers, we would need to set up the statistical inference tests because there are various number of different features that are being used to describe the playlists and we would need to determine if they datasets are appropriate to do hypothesis testing on. The features that have numerical values include: acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, valence, popularity and tempo. The features that are based on proportions are mode and explicitness.
#
# Does the hypothesis test meet the requirements?
#
# **Normality**- The sample size for each theme is over 30, therefore normality may be assumed. As for the features based on proportions, the number for each of the each of the features that are and are not in those populations are greater than ten. Therefore, normality condition can be assumed to be met for that as well.
#
# **Independence**- Since the population from which the songs are chosen from are the songs in the Spotify catalogue, which may have over 20M songs in its database. Because the sample size of the playlists is a tiny fraction of that (~100+ songs for each labeled playlist), independence can be assumed.
#
# **Randomness**- There may be some bias here as the songs for each playlist were chosen subjectively by a curator. However, it can be argued that this what we want. Also, when choosing from each of the playlists, the samples are randomly chosen without replacement using the bootstrap methods defined above.
#
# Hypothesis parameters:
#
# **H0**: The feature's mean value is the same for 'happy' songs versus 'sad' songs.
#
# **$\alpha$** = 0.001

# %%
# put data through hypothesis testing

feature_names = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 
            'loudness', 'speechiness', 'valence', 'tempo', 'popularity', 'mode', 'explicit']

for feature in feature_names:
    p_val = feature_p_value(df_combined[feature][df_combined['label']=='sad'], 
                            df_combined[feature][df_combined['label']=='happy'], 
                            np.mean)
    print(f"The p-value for {feature} is {p_val}.")
# Out:
# The p-value for acousticness is 0.0.
# The p-value for danceability is 0.0.
# The p-value for energy is 0.0.
# The p-value for instrumentalness is 0.7298.
# The p-value for liveness is 0.0.
# The p-value for loudness is 0.0.
# The p-value for speechiness is 0.0209.
# The p-value for valence is 0.0.
# The p-value for tempo is 0.0423.
# The p-value for popularity is 0.0339.
# The p-value for mode is 0.9767.
# The p-value for explicit is 0.03.

# %% [markdown]
# The above hypothesis testing for each of the mentioned features suggest according to the chosen $\alpha$ that the features following features have a significant difference between the two populations: acousticness, danceability, energy, liveness, loudness, and valence. According to the visual analysis in the previous, these were the features that were one would be able to see differences in the values. Therefore, this affirms that are differences in certain features between the two playlist themes.

# %% [markdown]
# ## Modeling

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# K-means Clustering

# %%
# apply KMeans to the matrix
from sklearn.cluster import KMeans

scaler = StandardScaler()
kmeans = KMeans(n_clusters=2)
pipeline1 = make_pipeline(scaler, kmeans)
clusters = pipeline1.fit_predict(x_cols)
# Out:
# c:\users\henta\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\henta\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
df_combined['clusters'] = clusters

# %%
df_combined
# Out:
#                                                                     album  \
# id
# 14JzyD6FlBD5z0wV5P07YI                              when the party's over
# 2aFC6EAvz25EC0osKd8PK0                                             Berlin
# 0Peh9vSnImMMTznniOJcsj                                       Loved by You
# 6usQ5BOBsRY5Dc49kwXsTw                                           Volume 1
# 4L2K7JKseFCBoHMZEAszW0                                            Jealous
# 4CYBfRX3oEPni9Elqm8Bnt                                       Lost & Found
# 1VbhR6D6zUoSTBzvnRonXO                In The Lonely Hour (Deluxe Edition)
# 3sfepRu8KYCfKoPOsH6ym3                                 So Cold (Acoustic)
# 6k8kLJFmWkHaTbSLUhJ3H0                          Birdy (Spotify Exclusive)
# 0c99BUd87HQfzgUUQqRyds                                     In the Waiting
# 0u2P5u6lvoDfwTYjAADbn4                               lovely (with Khalid)
# 6mHw0o12JUfDodSxMwp8TI                                    All We've Known
# 0mel2N9Ws9r4yLQn5QE21Y                               Too Good At Goodbyes
# 45iRSkMxq7aohzs3qu1ZtX                                          Would You
# 3wF0zyjQ6FKLK4vFxcMojP                                               Vain
# 1F7ZElvJAvWKQ7UaPXg9cF                                        Assume Form
# 3EPXxR3ImUwfayaurPi3cm                                         Be Alright
# 0pQlcs8qsOOLphM8laWr5v                                               Dawn
# 1fYouLdK3PkOMPnx4CPxTY                                Such A Simple Thing
# 5Cv1xqpyciZZuHHR7xr2l0                             the broken hearts club
# 6PmhCEPMjhSo9j8hz767xy                                      Summer's Gone
# 6r44uyKRo3jKFRkThTZBXu                                        Fire Escape
# 5vmSMCACbvvNyj71zAMRQ9                                   No Replacing You
# 22uyZjmZR0DX8FyrIwQl35                                  The Colder Months
# 4sVnlrSGaRwnBaj35C2wXu                                     After the Rain
# 3nVzM4S7hHDbyZMGyvtJdX                                         I Hate You
# 0u4rkpmNtgcFxYHepnVF4v                                      Bathing Beach
# 4bPkBHKLKd9WHizsvM2zV3                        A Rush Of Blood To The Head
# 5EKm2REw8HdwoadlQKffFJ                                        ii (Side A)
# 5NRl32BO29q8xtWFvOlHZE                               Know-It-All (Deluxe)
# ...                                                                   ...
# 5eGX87IiKsGuzS3iw4CfCX                                    Spotify Singles
# 6QgjcU0zLnzq5OrUoSZ3OK                                          Woodstock
# 5ntzu58JfhdotnHWSJR4mj                                  Total Hits Vol. 2
# 6DlxVlOMWDG71sNyaJtmTy                                       Sucker Punch
# 2Gy7qnDwt8Z3MNxqat4CsK   Pet Sounds (Original Mono & Stereo Mix Versions)
# 0KXDqw7VbJh2EMAE6hbqLA                  Follow Your Fire (Syn Cole Remix)
# 0Hw6SCrtU9pFCjgAONpnGZ                                           Up-Tight
# 0hK0PTJdd4Jx6Ryl4t8jTi                                       Paper Crowns
# 2ewW50QGufVvqP959lB8F9                                        Next Season
# 3VKDOXkmTHt4Xa78U4dbDp                                      Back Together
# 5yjOhc3JKrznGouRHMagoJ                                              Waves
# 2udw7RDkldLFIPG9WYdVtT                 Songs In The Key Of Life (Reissue)
# 0Y2SrByf4G3kbq2nBEHQRn              Music From The Motion Picture Michael
# 3T4UodGkfZObJ43RtA5KFU                                         Connection
# 3FNY26zMg3Zfe5Cbyu45uu                                          Moonlight
# 5PyRffCCs2KPPL5LFDGEs5                                     Head Held High
# 7dhh5MGe898uMm7TrCUvwj                                 How Did I Find You
# 01k24g94i1JvkFLQmVEdCd                                  If You're Over Me
# 2Pocbh1NXgLruVbUAlBh54                                        Motown Gold
# 5XBqGcLYOZi8CEW83Ug7Fs                                            Clearly
# 5Hroj5K7vLpIG4FNCRIjbP                                    Oh, What A Life
# 7FjZU7XFs7P9jHI9Z0yRhK                        So Close (feat. Georgia Ku)
# 4Xx4oojaE3MlJKpgtilgp1                                           Yung Luv
# 1xy4apMFecGGkgBeaHFZ2M                                       Chasing Fire
# 34awK00Tgp6KW6jgxiY5mR               Closer To You (feat. Sinéad Harnett)
# 5Ef2noaxqTAfa5gLVw05OJ                    You Come First (feat. Saweetie)
# 6wljt66ynO2xWA1KE9Elu5                                          Motown 50
# 18KOfFqQuVlcXhu0JRpUfN  The Ultimate Collection: Junior Walker And The...
# 0sooJd5WbNnnz5k6yO7FIQ                                 All This Bad Blood
# 5fNDP3NTdE69szQHUl4fFr      Forever: The Complete Motown Albums, Volume 1
#
#                                                                artist  \
# id
# 14JzyD6FlBD5z0wV5P07YI                                [Billie Eilish]
# 2aFC6EAvz25EC0osKd8PK0                                         [RY X]
# 0Peh9vSnImMMTznniOJcsj                                        [KIRBY]
# 6usQ5BOBsRY5Dc49kwXsTw                                  [Pink Sweat$]
# 4L2K7JKseFCBoHMZEAszW0                                     [Labrinth]
# 4CYBfRX3oEPni9Elqm8Bnt                                  [Jorja Smith]
# 1VbhR6D6zUoSTBzvnRonXO                                    [Sam Smith]
# 3sfepRu8KYCfKoPOsH6ym3                                   [Maria Lynn]
# 6k8kLJFmWkHaTbSLUhJ3H0                                        [Birdy]
# 0c99BUd87HQfzgUUQqRyds                                 [Kina Grannis]
# 0u2P5u6lvoDfwTYjAADbn4                        [Billie Eilish, Khalid]
# 6mHw0o12JUfDodSxMwp8TI                                         [Haux]
# 0mel2N9Ws9r4yLQn5QE21Y                                    [Sam Smith]
# 45iRSkMxq7aohzs3qu1ZtX                                  [Pink Sweat$]
# 3wF0zyjQ6FKLK4vFxcMojP                                        [KIRBY]
# 1F7ZElvJAvWKQ7UaPXg9cF                         [James Blake, ROSALÍA]
# 3EPXxR3ImUwfayaurPi3cm                                   [Dean Lewis]
# 0pQlcs8qsOOLphM8laWr5v                                         [RY X]
# 1fYouLdK3PkOMPnx4CPxTY                               [Ray LaMontagne]
# 5Cv1xqpyciZZuHHR7xr2l0                                        [gnash]
# 6PmhCEPMjhSo9j8hz767xy                                   [Maria Lynn]
# 6r44uyKRo3jKFRkThTZBXu                             [Imaginary Future]
# 5vmSMCACbvvNyj71zAMRQ9                                  [Pink Sweat$]
# 22uyZjmZR0DX8FyrIwQl35                                    [Liza Anne]
# 4sVnlrSGaRwnBaj35C2wXu                    [Benjamin Francis Leftwich]
# 3nVzM4S7hHDbyZMGyvtJdX                                         [Nani]
# 0u4rkpmNtgcFxYHepnVF4v                                    [Novo Amor]
# 4bPkBHKLKd9WHizsvM2zV3                                     [Coldplay]
# 5EKm2REw8HdwoadlQKffFJ                                       [Aquilo]
# 5NRl32BO29q8xtWFvOlHZE                                 [Alessia Cara]
# ...                                                               ...
# 5eGX87IiKsGuzS3iw4CfCX                                 [Taylor Swift]
# 6QgjcU0zLnzq5OrUoSZ3OK                            [Portugal. The Man]
# 5ntzu58JfhdotnHWSJR4mj                              [The Foundations]
# 6DlxVlOMWDG71sNyaJtmTy                                       [Sigrid]
# 2Gy7qnDwt8Z3MNxqat4CsK                               [The Beach Boys]
# 0KXDqw7VbJh2EMAE6hbqLA                           [Kodaline, Syn Cole]
# 0Hw6SCrtU9pFCjgAONpnGZ                                [Stevie Wonder]
# 0hK0PTJdd4Jx6Ryl4t8jTi        [Lost Kings, Wiz Khalifa, Social House]
# 2ewW50QGufVvqP959lB8F9              [Felix Cartal, Gabrielle Current]
# 3VKDOXkmTHt4Xa78U4dbDp                                        [Loote]
# 5yjOhc3JKrznGouRHMagoJ                               [Rachel Platten]
# 2udw7RDkldLFIPG9WYdVtT                                [Stevie Wonder]
# 0Y2SrByf4G3kbq2nBEHQRn                             [Norman Greenbaum]
# 3T4UodGkfZObJ43RtA5KFU                                  [OneRepublic]
# 3FNY26zMg3Zfe5Cbyu45uu                             [Grace VanderWaal]
# 5PyRffCCs2KPPL5LFDGEs5                                     [Kodaline]
# 7dhh5MGe898uMm7TrCUvwj                        [NEIKED, Miriam Bryant]
# 01k24g94i1JvkFLQmVEdCd                                [Years & Years]
# 2Pocbh1NXgLruVbUAlBh54                              [The Marvelettes]
# 5XBqGcLYOZi8CEW83Ug7Fs                             [Grace VanderWaal]
# 5Hroj5K7vLpIG4FNCRIjbP                             [American Authors]
# 7FjZU7XFs7P9jHI9Z0yRhK  [NOTD, Felix Jaehn, Captain Cuts, Georgia Ku]
# 4Xx4oojaE3MlJKpgtilgp1                    [Andrelli, Hearts & Colors]
# 1xy4apMFecGGkgBeaHFZ2M                                         [Lauv]
# 34awK00Tgp6KW6jgxiY5mR                   [Dan Caplen, Sinead Harnett]
# 5Ef2noaxqTAfa5gLVw05OJ                           [Zak Abel, Saweetie]
# 6wljt66ynO2xWA1KE9Elu5                              [The Temptations]
# 18KOfFqQuVlcXhu0JRpUfN                   [Jr. Walker & The All Stars]
# 0sooJd5WbNnnz5k6yO7FIQ                                     [Bastille]
# 5fNDP3NTdE69szQHUl4fFr                              [The Marvelettes]
#
#                         explicit  \
# id
# 14JzyD6FlBD5z0wV5P07YI     False
# 2aFC6EAvz25EC0osKd8PK0     False
# 0Peh9vSnImMMTznniOJcsj     False
# 6usQ5BOBsRY5Dc49kwXsTw     False
# 4L2K7JKseFCBoHMZEAszW0     False
# 4CYBfRX3oEPni9Elqm8Bnt     False
# 1VbhR6D6zUoSTBzvnRonXO     False
# 3sfepRu8KYCfKoPOsH6ym3     False
# 6k8kLJFmWkHaTbSLUhJ3H0     False
# 0c99BUd87HQfzgUUQqRyds     False
# 0u2P5u6lvoDfwTYjAADbn4     False
# 6mHw0o12JUfDodSxMwp8TI     False
# 0mel2N9Ws9r4yLQn5QE21Y     False
# 45iRSkMxq7aohzs3qu1ZtX     False
# 3wF0zyjQ6FKLK4vFxcMojP     False
# 1F7ZElvJAvWKQ7UaPXg9cF     False
# 3EPXxR3ImUwfayaurPi3cm      True
# 0pQlcs8qsOOLphM8laWr5v     False
# 1fYouLdK3PkOMPnx4CPxTY     False
# 5Cv1xqpyciZZuHHR7xr2l0     False
# 6PmhCEPMjhSo9j8hz767xy     False
# 6r44uyKRo3jKFRkThTZBXu     False
# 5vmSMCACbvvNyj71zAMRQ9     False
# 22uyZjmZR0DX8FyrIwQl35     False
# 4sVnlrSGaRwnBaj35C2wXu     False
# 3nVzM4S7hHDbyZMGyvtJdX     False
# 0u4rkpmNtgcFxYHepnVF4v     False
# 4bPkBHKLKd9WHizsvM2zV3     False
# 5EKm2REw8HdwoadlQKffFJ     False
# 5NRl32BO29q8xtWFvOlHZE     False
# ...                          ...
# 5eGX87IiKsGuzS3iw4CfCX     False
# 6QgjcU0zLnzq5OrUoSZ3OK     False
# 5ntzu58JfhdotnHWSJR4mj     False
# 6DlxVlOMWDG71sNyaJtmTy      True
# 2Gy7qnDwt8Z3MNxqat4CsK     False
# 0KXDqw7VbJh2EMAE6hbqLA     False
# 0Hw6SCrtU9pFCjgAONpnGZ     False
# 0hK0PTJdd4Jx6Ryl4t8jTi      True
# 2ewW50QGufVvqP959lB8F9     False
# 3VKDOXkmTHt4Xa78U4dbDp     False
# 5yjOhc3JKrznGouRHMagoJ     False
# 2udw7RDkldLFIPG9WYdVtT     False
# 0Y2SrByf4G3kbq2nBEHQRn     False
# 3T4UodGkfZObJ43RtA5KFU     False
# 3FNY26zMg3Zfe5Cbyu45uu     False
# 5PyRffCCs2KPPL5LFDGEs5     False
# 7dhh5MGe898uMm7TrCUvwj     False
# 01k24g94i1JvkFLQmVEdCd     False
# 2Pocbh1NXgLruVbUAlBh54     False
# 5XBqGcLYOZi8CEW83Ug7Fs     False
# 5Hroj5K7vLpIG4FNCRIjbP     False
# 7FjZU7XFs7P9jHI9Z0yRhK     False
# 4Xx4oojaE3MlJKpgtilgp1     False
# 1xy4apMFecGGkgBeaHFZ2M     False
# 34awK00Tgp6KW6jgxiY5mR     False
# 5Ef2noaxqTAfa5gLVw05OJ     False
# 6wljt66ynO2xWA1KE9Elu5     False
# 18KOfFqQuVlcXhu0JRpUfN     False
# 0sooJd5WbNnnz5k6yO7FIQ     False
# 5fNDP3NTdE69szQHUl4fFr     False
#
#                                                                      name  \
# id
# 14JzyD6FlBD5z0wV5P07YI                              when the party's over
# 2aFC6EAvz25EC0osKd8PK0                                             Berlin
# 0Peh9vSnImMMTznniOJcsj                                       Loved by You
# 6usQ5BOBsRY5Dc49kwXsTw                                            Cocaine
# 4L2K7JKseFCBoHMZEAszW0                                            Jealous
# 4CYBfRX3oEPni9Elqm8Bnt                                           Goodbyes
# 1VbhR6D6zUoSTBzvnRonXO                               I'm Not The Only One
# 3sfepRu8KYCfKoPOsH6ym3                                 So Cold (Acoustic)
# 6k8kLJFmWkHaTbSLUhJ3H0                                        Skinny Love
# 0c99BUd87HQfzgUUQqRyds                                            For Now
# 0u2P5u6lvoDfwTYjAADbn4                               lovely (with Khalid)
# 6mHw0o12JUfDodSxMwp8TI                                              Caves
# 0mel2N9Ws9r4yLQn5QE21Y                        Too Good At Goodbyes - Edit
# 45iRSkMxq7aohzs3qu1ZtX                                          Would You
# 3wF0zyjQ6FKLK4vFxcMojP                                               Vain
# 1F7ZElvJAvWKQ7UaPXg9cF                               Barefoot In The Park
# 3EPXxR3ImUwfayaurPi3cm                                         Be Alright
# 0pQlcs8qsOOLphM8laWr5v                                              Sweat
# 1fYouLdK3PkOMPnx4CPxTY                                Such A Simple Thing
# 5Cv1xqpyciZZuHHR7xr2l0                             the broken hearts club
# 6PmhCEPMjhSo9j8hz767xy                                      Summer's Gone
# 6r44uyKRo3jKFRkThTZBXu                          I Knew This Would Be Love
# 5vmSMCACbvvNyj71zAMRQ9                                   No Replacing You
# 22uyZjmZR0DX8FyrIwQl35                                        1,000 Years
# 4sVnlrSGaRwnBaj35C2wXu                                            Tilikum
# 3nVzM4S7hHDbyZMGyvtJdX                                         I Hate You
# 0u4rkpmNtgcFxYHepnVF4v                                          Carry You
# 4bPkBHKLKd9WHizsvM2zV3                                       Warning Sign
# 5EKm2REw8HdwoadlQKffFJ                                        Who Are You
# 5NRl32BO29q8xtWFvOlHZE                                     River Of Tears
# ...                                                                   ...
# 5eGX87IiKsGuzS3iw4CfCX  September - Recorded at The Tracking Room Nash...
# 6QgjcU0zLnzq5OrUoSZ3OK                                      Feel It Still
# 5ntzu58JfhdotnHWSJR4mj                              Build Me Up Buttercup
# 6DlxVlOMWDG71sNyaJtmTy                                       Sucker Punch
# 2Gy7qnDwt8Z3MNxqat4CsK                   Wouldn't It Be Nice - Stereo Mix
# 0KXDqw7VbJh2EMAE6hbqLA                  Follow Your Fire - Syn Cole Remix
# 0Hw6SCrtU9pFCjgAONpnGZ                     Uptight (Everything's Alright)
# 0hK0PTJdd4Jx6Ryl4t8jTi  Don't Kill My High (feat. Wiz Khalifa & Social...
# 2ewW50QGufVvqP959lB8F9                                Stop Being Yourself
# 3VKDOXkmTHt4Xa78U4dbDp                                      Back Together
# 5yjOhc3JKrznGouRHMagoJ                                            Shivers
# 2udw7RDkldLFIPG9WYdVtT                                           Sir Duke
# 0Y2SrByf4G3kbq2nBEHQRn                                  Spirit in the Sky
# 3T4UodGkfZObJ43RtA5KFU                                         Connection
# 3FNY26zMg3Zfe5Cbyu45uu                                          Moonlight
# 5PyRffCCs2KPPL5LFDGEs5                                     Head Held High
# 7dhh5MGe898uMm7TrCUvwj                                 How Did I Find You
# 01k24g94i1JvkFLQmVEdCd                                  If You're Over Me
# 2Pocbh1NXgLruVbUAlBh54                                   Beechwood 4-5789
# 5XBqGcLYOZi8CEW83Ug7Fs                                            Clearly
# 5Hroj5K7vLpIG4FNCRIjbP                                Best Day Of My Life
# 7FjZU7XFs7P9jHI9Z0yRhK                                           So Close
# 4Xx4oojaE3MlJKpgtilgp1                                           Yung Luv
# 1xy4apMFecGGkgBeaHFZ2M                                       Chasing Fire
# 34awK00Tgp6KW6jgxiY5mR               Closer To You (feat. Sinéad Harnett)
# 5Ef2noaxqTAfa5gLVw05OJ                    You Come First (feat. Saweetie)
# 6wljt66ynO2xWA1KE9Elu5                             Ain't Too Proud To Beg
# 18KOfFqQuVlcXhu0JRpUfN                                            Shotgun
# 0sooJd5WbNnnz5k6yO7FIQ                                            Pompeii
# 5fNDP3NTdE69szQHUl4fFr                Please Mr. Postman - Stereo Version
#
#                         popularity  acousticness  \
# id
# 14JzyD6FlBD5z0wV5P07YI          92      0.979000
# 2aFC6EAvz25EC0osKd8PK0          51      0.967000
# 0Peh9vSnImMMTznniOJcsj          48      0.963000
# 6usQ5BOBsRY5Dc49kwXsTw          64      0.836000
# 4L2K7JKseFCBoHMZEAszW0          78      0.873000
# 4CYBfRX3oEPni9Elqm8Bnt          66      0.866000
# 1VbhR6D6zUoSTBzvnRonXO          17      0.565000
# 3sfepRu8KYCfKoPOsH6ym3          50      0.761000
# 6k8kLJFmWkHaTbSLUhJ3H0          60      0.952000
# 0c99BUd87HQfzgUUQqRyds          67      0.926000
# 0u2P5u6lvoDfwTYjAADbn4          90      0.934000
# 6mHw0o12JUfDodSxMwp8TI          54      0.289000
# 0mel2N9Ws9r4yLQn5QE21Y          27      0.658000
# 45iRSkMxq7aohzs3qu1ZtX          61      0.697000
# 3wF0zyjQ6FKLK4vFxcMojP          42      0.629000
# 1F7ZElvJAvWKQ7UaPXg9cF          67      0.832000
# 3EPXxR3ImUwfayaurPi3cm          91      0.697000
# 0pQlcs8qsOOLphM8laWr5v          47      0.909000
# 1fYouLdK3PkOMPnx4CPxTY          70      0.860000
# 5Cv1xqpyciZZuHHR7xr2l0          60      0.801000
# 6PmhCEPMjhSo9j8hz767xy          57      0.835000
# 6r44uyKRo3jKFRkThTZBXu          58      0.958000
# 5vmSMCACbvvNyj71zAMRQ9          61      0.726000
# 22uyZjmZR0DX8FyrIwQl35          58      0.645000
# 4sVnlrSGaRwnBaj35C2wXu          55      0.926000
# 3nVzM4S7hHDbyZMGyvtJdX          45      0.315000
# 0u4rkpmNtgcFxYHepnVF4v          65      0.558000
# 4bPkBHKLKd9WHizsvM2zV3          60      0.093200
# 5EKm2REw8HdwoadlQKffFJ           4      0.778000
# 5NRl32BO29q8xtWFvOlHZE          65      0.928000
# ...                            ...           ...
# 5eGX87IiKsGuzS3iw4CfCX          67      0.412000
# 6QgjcU0zLnzq5OrUoSZ3OK          82      0.041700
# 5ntzu58JfhdotnHWSJR4mj          13      0.389000
# 6DlxVlOMWDG71sNyaJtmTy          54      0.001530
# 2Gy7qnDwt8Z3MNxqat4CsK          71      0.718000
# 0KXDqw7VbJh2EMAE6hbqLA          55      0.008720
# 0Hw6SCrtU9pFCjgAONpnGZ          56      0.179000
# 0hK0PTJdd4Jx6Ryl4t8jTi          57      0.036300
# 2ewW50QGufVvqP959lB8F9          65      0.012700
# 3VKDOXkmTHt4Xa78U4dbDp          61      0.239000
# 5yjOhc3JKrznGouRHMagoJ          62      0.093400
# 2udw7RDkldLFIPG9WYdVtT          22      0.160000
# 0Y2SrByf4G3kbq2nBEHQRn          68      0.112000
# 3T4UodGkfZObJ43RtA5KFU          76      0.000837
# 3FNY26zMg3Zfe5Cbyu45uu          14      0.399000
# 5PyRffCCs2KPPL5LFDGEs5          62      0.008180
# 7dhh5MGe898uMm7TrCUvwj          54      0.244000
# 01k24g94i1JvkFLQmVEdCd          75      0.061500
# 2Pocbh1NXgLruVbUAlBh54          31      0.521000
# 5XBqGcLYOZi8CEW83Ug7Fs          65      0.125000
# 5Hroj5K7vLpIG4FNCRIjbP          75      0.062900
# 7FjZU7XFs7P9jHI9Z0yRhK          85      0.121000
# 4Xx4oojaE3MlJKpgtilgp1          63      0.219000
# 1xy4apMFecGGkgBeaHFZ2M          72      0.044900
# 34awK00Tgp6KW6jgxiY5mR          55      0.106000
# 5Ef2noaxqTAfa5gLVw05OJ          70      0.035200
# 6wljt66ynO2xWA1KE9Elu5           9      0.371000
# 18KOfFqQuVlcXhu0JRpUfN          37      0.115000
# 0sooJd5WbNnnz5k6yO7FIQ          21      0.074000
# 5fNDP3NTdE69szQHUl4fFr          55      0.693000
#
#                                                              analysis_url  \
# id
# 14JzyD6FlBD5z0wV5P07YI  https://api.spotify.com/v1/audio-analysis/14Jz...
# 2aFC6EAvz25EC0osKd8PK0  https://api.spotify.com/v1/audio-analysis/2aFC...
# 0Peh9vSnImMMTznniOJcsj  https://api.spotify.com/v1/audio-analysis/0Peh...
# 6usQ5BOBsRY5Dc49kwXsTw  https://api.spotify.com/v1/audio-analysis/6usQ...
# 4L2K7JKseFCBoHMZEAszW0  https://api.spotify.com/v1/audio-analysis/4L2K...
# 4CYBfRX3oEPni9Elqm8Bnt  https://api.spotify.com/v1/audio-analysis/4CYB...
# 1VbhR6D6zUoSTBzvnRonXO  https://api.spotify.com/v1/audio-analysis/1Vbh...
# 3sfepRu8KYCfKoPOsH6ym3  https://api.spotify.com/v1/audio-analysis/3sfe...
# 6k8kLJFmWkHaTbSLUhJ3H0  https://api.spotify.com/v1/audio-analysis/6k8k...
# 0c99BUd87HQfzgUUQqRyds  https://api.spotify.com/v1/audio-analysis/0c99...
# 0u2P5u6lvoDfwTYjAADbn4  https://api.spotify.com/v1/audio-analysis/0u2P...
# 6mHw0o12JUfDodSxMwp8TI  https://api.spotify.com/v1/audio-analysis/6mHw...
# 0mel2N9Ws9r4yLQn5QE21Y  https://api.spotify.com/v1/audio-analysis/0mel...
# 45iRSkMxq7aohzs3qu1ZtX  https://api.spotify.com/v1/audio-analysis/45iR...
# 3wF0zyjQ6FKLK4vFxcMojP  https://api.spotify.com/v1/audio-analysis/3wF0...
# 1F7ZElvJAvWKQ7UaPXg9cF  https://api.spotify.com/v1/audio-analysis/1F7Z...
# 3EPXxR3ImUwfayaurPi3cm  https://api.spotify.com/v1/audio-analysis/3EPX...
# 0pQlcs8qsOOLphM8laWr5v  https://api.spotify.com/v1/audio-analysis/0pQl...
# 1fYouLdK3PkOMPnx4CPxTY  https://api.spotify.com/v1/audio-analysis/1fYo...
# 5Cv1xqpyciZZuHHR7xr2l0  https://api.spotify.com/v1/audio-analysis/5Cv1...
# 6PmhCEPMjhSo9j8hz767xy  https://api.spotify.com/v1/audio-analysis/6Pmh...
# 6r44uyKRo3jKFRkThTZBXu  https://api.spotify.com/v1/audio-analysis/6r44...
# 5vmSMCACbvvNyj71zAMRQ9  https://api.spotify.com/v1/audio-analysis/5vmS...
# 22uyZjmZR0DX8FyrIwQl35  https://api.spotify.com/v1/audio-analysis/22uy...
# 4sVnlrSGaRwnBaj35C2wXu  https://api.spotify.com/v1/audio-analysis/4sVn...
# 3nVzM4S7hHDbyZMGyvtJdX  https://api.spotify.com/v1/audio-analysis/3nVz...
# 0u4rkpmNtgcFxYHepnVF4v  https://api.spotify.com/v1/audio-analysis/0u4r...
# 4bPkBHKLKd9WHizsvM2zV3  https://api.spotify.com/v1/audio-analysis/4bPk...
# 5EKm2REw8HdwoadlQKffFJ  https://api.spotify.com/v1/audio-analysis/5EKm...
# 5NRl32BO29q8xtWFvOlHZE  https://api.spotify.com/v1/audio-analysis/5NRl...
# ...                                                                   ...
# 5eGX87IiKsGuzS3iw4CfCX  https://api.spotify.com/v1/audio-analysis/5eGX...
# 6QgjcU0zLnzq5OrUoSZ3OK  https://api.spotify.com/v1/audio-analysis/6Qgj...
# 5ntzu58JfhdotnHWSJR4mj  https://api.spotify.com/v1/audio-analysis/5ntz...
# 6DlxVlOMWDG71sNyaJtmTy  https://api.spotify.com/v1/audio-analysis/6Dlx...
# 2Gy7qnDwt8Z3MNxqat4CsK  https://api.spotify.com/v1/audio-analysis/2Gy7...
# 0KXDqw7VbJh2EMAE6hbqLA  https://api.spotify.com/v1/audio-analysis/0KXD...
# 0Hw6SCrtU9pFCjgAONpnGZ  https://api.spotify.com/v1/audio-analysis/0Hw6...
# 0hK0PTJdd4Jx6Ryl4t8jTi  https://api.spotify.com/v1/audio-analysis/0hK0...
# 2ewW50QGufVvqP959lB8F9  https://api.spotify.com/v1/audio-analysis/2ewW...
# 3VKDOXkmTHt4Xa78U4dbDp  https://api.spotify.com/v1/audio-analysis/3VKD...
# 5yjOhc3JKrznGouRHMagoJ  https://api.spotify.com/v1/audio-analysis/5yjO...
# 2udw7RDkldLFIPG9WYdVtT  https://api.spotify.com/v1/audio-analysis/2udw...
# 0Y2SrByf4G3kbq2nBEHQRn  https://api.spotify.com/v1/audio-analysis/0Y2S...
# 3T4UodGkfZObJ43RtA5KFU  https://api.spotify.com/v1/audio-analysis/3T4U...
# 3FNY26zMg3Zfe5Cbyu45uu  https://api.spotify.com/v1/audio-analysis/3FNY...
# 5PyRffCCs2KPPL5LFDGEs5  https://api.spotify.com/v1/audio-analysis/5PyR...
# 7dhh5MGe898uMm7TrCUvwj  https://api.spotify.com/v1/audio-analysis/7dhh...
# 01k24g94i1JvkFLQmVEdCd  https://api.spotify.com/v1/audio-analysis/01k2...
# 2Pocbh1NXgLruVbUAlBh54  https://api.spotify.com/v1/audio-analysis/2Poc...
# 5XBqGcLYOZi8CEW83Ug7Fs  https://api.spotify.com/v1/audio-analysis/5XBq...
# 5Hroj5K7vLpIG4FNCRIjbP  https://api.spotify.com/v1/audio-analysis/5Hro...
# 7FjZU7XFs7P9jHI9Z0yRhK  https://api.spotify.com/v1/audio-analysis/7FjZ...
# 4Xx4oojaE3MlJKpgtilgp1  https://api.spotify.com/v1/audio-analysis/4Xx4...
# 1xy4apMFecGGkgBeaHFZ2M  https://api.spotify.com/v1/audio-analysis/1xy4...
# 34awK00Tgp6KW6jgxiY5mR  https://api.spotify.com/v1/audio-analysis/34aw...
# 5Ef2noaxqTAfa5gLVw05OJ  https://api.spotify.com/v1/audio-analysis/5Ef2...
# 6wljt66ynO2xWA1KE9Elu5  https://api.spotify.com/v1/audio-analysis/6wlj...
# 18KOfFqQuVlcXhu0JRpUfN  https://api.spotify.com/v1/audio-analysis/18KO...
# 0sooJd5WbNnnz5k6yO7FIQ  https://api.spotify.com/v1/audio-analysis/0soo...
# 5fNDP3NTdE69szQHUl4fFr  https://api.spotify.com/v1/audio-analysis/5fND...
#
#                         danceability  duration_ms  energy   ...       tempo  \
# id                                                          ...
# 14JzyD6FlBD5z0wV5P07YI         0.498       199931  0.1040   ...     124.001
# 2aFC6EAvz25EC0osKd8PK0         0.396       170551  0.0695   ...     137.149
# 0Peh9vSnImMMTznniOJcsj         0.643       256000  0.1700   ...      79.282
# 6usQ5BOBsRY5Dc49kwXsTw         0.455       131500  0.2280   ...     118.499
# 4L2K7JKseFCBoHMZEAszW0         0.435       287693  0.1550   ...     128.532
# 4CYBfRX3oEPni9Elqm8Bnt         0.512       230930  0.1840   ...      85.820
# 1VbhR6D6zUoSTBzvnRonXO         0.678       239317  0.4910   ...      81.997
# 3sfepRu8KYCfKoPOsH6ym3         0.512       199647  0.2630   ...     139.772
# 6k8kLJFmWkHaTbSLUhJ3H0         0.379       201080  0.2900   ...     166.467
# 0c99BUd87HQfzgUUQqRyds         0.397       198404  0.2490   ...      79.614
# 0u2P5u6lvoDfwTYjAADbn4         0.351       200186  0.2960   ...     115.284
# 6mHw0o12JUfDodSxMwp8TI         0.554       233240  0.3180   ...     130.110
# 0mel2N9Ws9r4yLQn5QE21Y         0.653       201000  0.3780   ...      91.835
# 45iRSkMxq7aohzs3qu1ZtX         0.710       153125  0.1900   ...     105.140
# 3wF0zyjQ6FKLK4vFxcMojP         0.605       245323  0.1910   ...     124.233
# 1F7ZElvJAvWKQ7UaPXg9cF         0.558       211200  0.6320   ...     161.764
# 3EPXxR3ImUwfayaurPi3cm         0.553       196373  0.5860   ...     126.684
# 0pQlcs8qsOOLphM8laWr5v         0.400       239123  0.1060   ...      85.593
# 1fYouLdK3PkOMPnx4CPxTY         0.522       296387  0.2560   ...      76.350
# 5Cv1xqpyciZZuHHR7xr2l0         0.620       184468  0.2880   ...     100.385
# 6PmhCEPMjhSo9j8hz767xy         0.483       204205  0.2710   ...      86.856
# 6r44uyKRo3jKFRkThTZBXu         0.643       210202  0.1170   ...     120.611
# 5vmSMCACbvvNyj71zAMRQ9         0.596       167442  0.3200   ...      81.711
# 22uyZjmZR0DX8FyrIwQl35         0.437       219000  0.3010   ...     126.016
# 4sVnlrSGaRwnBaj35C2wXu         0.457       286747  0.3240   ...     129.131
# 3nVzM4S7hHDbyZMGyvtJdX         0.417       212139  0.6300   ...      78.607
# 0u4rkpmNtgcFxYHepnVF4v         0.334       273107  0.3970   ...      92.291
# 4bPkBHKLKd9WHizsvM2zV3         0.534       331133  0.4340   ...     140.632
# 5EKm2REw8HdwoadlQKffFJ         0.365       184740  0.4870   ...     130.025
# 5NRl32BO29q8xtWFvOlHZE         0.388       254507  0.3720   ...      89.701
# ...                              ...          ...     ...   ...         ...
# 5eGX87IiKsGuzS3iw4CfCX         0.641       187824  0.4440   ...     107.081
# 6QgjcU0zLnzq5OrUoSZ3OK         0.801       163253  0.7950   ...      79.028
# 5ntzu58JfhdotnHWSJR4mj         0.599       179840  0.6100   ...      66.776
# 6DlxVlOMWDG71sNyaJtmTy         0.638       194323  0.6420   ...     165.984
# 2Gy7qnDwt8Z3MNxqat4CsK         0.392       153240  0.6290   ...     124.511
# 0KXDqw7VbJh2EMAE6hbqLA         0.628       186923  0.9170   ...     103.991
# 0Hw6SCrtU9pFCjgAONpnGZ         0.598       174400  0.6460   ...     133.287
# 0hK0PTJdd4Jx6Ryl4t8jTi         0.674       180333  0.9320   ...     144.039
# 2ewW50QGufVvqP959lB8F9         0.662       249756  0.7300   ...     122.960
# 3VKDOXkmTHt4Xa78U4dbDp         0.777       183280  0.5790   ...     110.007
# 5yjOhc3JKrznGouRHMagoJ         0.838       175333  0.7240   ...     112.992
# 2udw7RDkldLFIPG9WYdVtT         0.588       232760  0.5680   ...     106.938
# 0Y2SrByf4G3kbq2nBEHQRn         0.601       239600  0.6430   ...     128.262
# 3T4UodGkfZObJ43RtA5KFU         0.611       148460  0.6020   ...     168.154
# 3FNY26zMg3Zfe5Cbyu45uu         0.737       174107  0.7340   ...      91.999
# 5PyRffCCs2KPPL5LFDGEs5         0.527       214880  0.9410   ...      94.056
# 7dhh5MGe898uMm7TrCUvwj         0.660       168823  0.7410   ...     101.973
# 01k24g94i1JvkFLQmVEdCd         0.647       189000  0.8530   ...     103.846
# 2Pocbh1NXgLruVbUAlBh54         0.616       131867  0.6070   ...     138.392
# 5XBqGcLYOZi8CEW83Ug7Fs         0.663       251907  0.6730   ...      98.000
# 5Hroj5K7vLpIG4FNCRIjbP         0.673       194240  0.9020   ...     100.016
# 7FjZU7XFs7P9jHI9Z0yRhK         0.700       190302  0.8720   ...     125.030
# 4Xx4oojaE3MlJKpgtilgp1         0.633       210000  0.5480   ...     173.994
# 1xy4apMFecGGkgBeaHFZ2M         0.709       205267  0.5620   ...     125.965
# 34awK00Tgp6KW6jgxiY5mR         0.796       196118  0.6030   ...      98.011
# 5Ef2noaxqTAfa5gLVw05OJ         0.745       191255  0.7190   ...      99.962
# 6wljt66ynO2xWA1KE9Elu5         0.756       151560  0.7830   ...     119.486
# 18KOfFqQuVlcXhu0JRpUfN         0.702       179800  0.8060   ...     120.517
# 0sooJd5WbNnnz5k6yO7FIQ         0.682       214148  0.7140   ...     127.443
# 5fNDP3NTdE69szQHUl4fFr         0.779       149400  0.8240   ...     120.588
#
#                         time_signature  \
# id
# 14JzyD6FlBD5z0wV5P07YI               3
# 2aFC6EAvz25EC0osKd8PK0               4
# 0Peh9vSnImMMTznniOJcsj               3
# 6usQ5BOBsRY5Dc49kwXsTw               3
# 4L2K7JKseFCBoHMZEAszW0               3
# 4CYBfRX3oEPni9Elqm8Bnt               4
# 1VbhR6D6zUoSTBzvnRonXO               4
# 3sfepRu8KYCfKoPOsH6ym3               4
# 6k8kLJFmWkHaTbSLUhJ3H0               4
# 0c99BUd87HQfzgUUQqRyds               4
# 0u2P5u6lvoDfwTYjAADbn4               4
# 6mHw0o12JUfDodSxMwp8TI               4
# 0mel2N9Ws9r4yLQn5QE21Y               4
# 45iRSkMxq7aohzs3qu1ZtX               4
# 3wF0zyjQ6FKLK4vFxcMojP               3
# 1F7ZElvJAvWKQ7UaPXg9cF               4
# 3EPXxR3ImUwfayaurPi3cm               4
# 0pQlcs8qsOOLphM8laWr5v               4
# 1fYouLdK3PkOMPnx4CPxTY               4
# 5Cv1xqpyciZZuHHR7xr2l0               4
# 6PmhCEPMjhSo9j8hz767xy               4
# 6r44uyKRo3jKFRkThTZBXu               4
# 5vmSMCACbvvNyj71zAMRQ9               4
# 22uyZjmZR0DX8FyrIwQl35               4
# 4sVnlrSGaRwnBaj35C2wXu               4
# 3nVzM4S7hHDbyZMGyvtJdX               4
# 0u4rkpmNtgcFxYHepnVF4v               4
# 4bPkBHKLKd9WHizsvM2zV3               4
# 5EKm2REw8HdwoadlQKffFJ               3
# 5NRl32BO29q8xtWFvOlHZE               4
# ...                                ...
# 5eGX87IiKsGuzS3iw4CfCX               4
# 6QgjcU0zLnzq5OrUoSZ3OK               4
# 5ntzu58JfhdotnHWSJR4mj               4
# 6DlxVlOMWDG71sNyaJtmTy               4
# 2Gy7qnDwt8Z3MNxqat4CsK               4
# 0KXDqw7VbJh2EMAE6hbqLA               4
# 0Hw6SCrtU9pFCjgAONpnGZ               4
# 0hK0PTJdd4Jx6Ryl4t8jTi               4
# 2ewW50QGufVvqP959lB8F9               4
# 3VKDOXkmTHt4Xa78U4dbDp               4
# 5yjOhc3JKrznGouRHMagoJ               4
# 2udw7RDkldLFIPG9WYdVtT               4
# 0Y2SrByf4G3kbq2nBEHQRn               4
# 3T4UodGkfZObJ43RtA5KFU               4
# 3FNY26zMg3Zfe5Cbyu45uu               4
# 5PyRffCCs2KPPL5LFDGEs5               4
# 7dhh5MGe898uMm7TrCUvwj               4
# 01k24g94i1JvkFLQmVEdCd               4
# 2Pocbh1NXgLruVbUAlBh54               4
# 5XBqGcLYOZi8CEW83Ug7Fs               4
# 5Hroj5K7vLpIG4FNCRIjbP               4
# 7FjZU7XFs7P9jHI9Z0yRhK               4
# 4Xx4oojaE3MlJKpgtilgp1               4
# 1xy4apMFecGGkgBeaHFZ2M               4
# 34awK00Tgp6KW6jgxiY5mR               4
# 5Ef2noaxqTAfa5gLVw05OJ               4
# 6wljt66ynO2xWA1KE9Elu5               4
# 18KOfFqQuVlcXhu0JRpUfN               4
# 0sooJd5WbNnnz5k6yO7FIQ               4
# 5fNDP3NTdE69szQHUl4fFr               4
#
#                                                                track_href  \
# id
# 14JzyD6FlBD5z0wV5P07YI  https://api.spotify.com/v1/tracks/14JzyD6FlBD5...
# 2aFC6EAvz25EC0osKd8PK0  https://api.spotify.com/v1/tracks/2aFC6EAvz25E...
# 0Peh9vSnImMMTznniOJcsj  https://api.spotify.com/v1/tracks/0Peh9vSnImMM...
# 6usQ5BOBsRY5Dc49kwXsTw  https://api.spotify.com/v1/tracks/6usQ5BOBsRY5...
# 4L2K7JKseFCBoHMZEAszW0  https://api.spotify.com/v1/tracks/4L2K7JKseFCB...
# 4CYBfRX3oEPni9Elqm8Bnt  https://api.spotify.com/v1/tracks/4CYBfRX3oEPn...
# 1VbhR6D6zUoSTBzvnRonXO  https://api.spotify.com/v1/tracks/1VbhR6D6zUoS...
# 3sfepRu8KYCfKoPOsH6ym3  https://api.spotify.com/v1/tracks/3sfepRu8KYCf...
# 6k8kLJFmWkHaTbSLUhJ3H0  https://api.spotify.com/v1/tracks/6k8kLJFmWkHa...
# 0c99BUd87HQfzgUUQqRyds  https://api.spotify.com/v1/tracks/0c99BUd87HQf...
# 0u2P5u6lvoDfwTYjAADbn4  https://api.spotify.com/v1/tracks/0u2P5u6lvoDf...
# 6mHw0o12JUfDodSxMwp8TI  https://api.spotify.com/v1/tracks/6mHw0o12JUfD...
# 0mel2N9Ws9r4yLQn5QE21Y  https://api.spotify.com/v1/tracks/0mel2N9Ws9r4...
# 45iRSkMxq7aohzs3qu1ZtX  https://api.spotify.com/v1/tracks/45iRSkMxq7ao...
# 3wF0zyjQ6FKLK4vFxcMojP  https://api.spotify.com/v1/tracks/3wF0zyjQ6FKL...
# 1F7ZElvJAvWKQ7UaPXg9cF  https://api.spotify.com/v1/tracks/1F7ZElvJAvWK...
# 3EPXxR3ImUwfayaurPi3cm  https://api.spotify.com/v1/tracks/3EPXxR3ImUwf...
# 0pQlcs8qsOOLphM8laWr5v  https://api.spotify.com/v1/tracks/0pQlcs8qsOOL...
# 1fYouLdK3PkOMPnx4CPxTY  https://api.spotify.com/v1/tracks/1fYouLdK3PkO...
# 5Cv1xqpyciZZuHHR7xr2l0  https://api.spotify.com/v1/tracks/5Cv1xqpyciZZ...
# 6PmhCEPMjhSo9j8hz767xy  https://api.spotify.com/v1/tracks/6PmhCEPMjhSo...
# 6r44uyKRo3jKFRkThTZBXu  https://api.spotify.com/v1/tracks/6r44uyKRo3jK...
# 5vmSMCACbvvNyj71zAMRQ9  https://api.spotify.com/v1/tracks/5vmSMCACbvvN...
# 22uyZjmZR0DX8FyrIwQl35  https://api.spotify.com/v1/tracks/22uyZjmZR0DX...
# 4sVnlrSGaRwnBaj35C2wXu  https://api.spotify.com/v1/tracks/4sVnlrSGaRwn...
# 3nVzM4S7hHDbyZMGyvtJdX  https://api.spotify.com/v1/tracks/3nVzM4S7hHDb...
# 0u4rkpmNtgcFxYHepnVF4v  https://api.spotify.com/v1/tracks/0u4rkpmNtgcF...
# 4bPkBHKLKd9WHizsvM2zV3  https://api.spotify.com/v1/tracks/4bPkBHKLKd9W...
# 5EKm2REw8HdwoadlQKffFJ  https://api.spotify.com/v1/tracks/5EKm2REw8Hdw...
# 5NRl32BO29q8xtWFvOlHZE  https://api.spotify.com/v1/tracks/5NRl32BO29q8...
# ...                                                                   ...
# 5eGX87IiKsGuzS3iw4CfCX  https://api.spotify.com/v1/tracks/5eGX87IiKsGu...
# 6QgjcU0zLnzq5OrUoSZ3OK  https://api.spotify.com/v1/tracks/6QgjcU0zLnzq...
# 5ntzu58JfhdotnHWSJR4mj  https://api.spotify.com/v1/tracks/5ntzu58Jfhdo...
# 6DlxVlOMWDG71sNyaJtmTy  https://api.spotify.com/v1/tracks/6DlxVlOMWDG7...
# 2Gy7qnDwt8Z3MNxqat4CsK  https://api.spotify.com/v1/tracks/2Gy7qnDwt8Z3...
# 0KXDqw7VbJh2EMAE6hbqLA  https://api.spotify.com/v1/tracks/0KXDqw7VbJh2...
# 0Hw6SCrtU9pFCjgAONpnGZ  https://api.spotify.com/v1/tracks/0Hw6SCrtU9pF...
# 0hK0PTJdd4Jx6Ryl4t8jTi  https://api.spotify.com/v1/tracks/0hK0PTJdd4Jx...
# 2ewW50QGufVvqP959lB8F9  https://api.spotify.com/v1/tracks/2ewW50QGufVv...
# 3VKDOXkmTHt4Xa78U4dbDp  https://api.spotify.com/v1/tracks/3VKDOXkmTHt4...
# 5yjOhc3JKrznGouRHMagoJ  https://api.spotify.com/v1/tracks/5yjOhc3JKrzn...
# 2udw7RDkldLFIPG9WYdVtT  https://api.spotify.com/v1/tracks/2udw7RDkldLF...
# 0Y2SrByf4G3kbq2nBEHQRn  https://api.spotify.com/v1/tracks/0Y2SrByf4G3k...
# 3T4UodGkfZObJ43RtA5KFU  https://api.spotify.com/v1/tracks/3T4UodGkfZOb...
# 3FNY26zMg3Zfe5Cbyu45uu  https://api.spotify.com/v1/tracks/3FNY26zMg3Zf...
# 5PyRffCCs2KPPL5LFDGEs5  https://api.spotify.com/v1/tracks/5PyRffCCs2KP...
# 7dhh5MGe898uMm7TrCUvwj  https://api.spotify.com/v1/tracks/7dhh5MGe898u...
# 01k24g94i1JvkFLQmVEdCd  https://api.spotify.com/v1/tracks/01k24g94i1Jv...
# 2Pocbh1NXgLruVbUAlBh54  https://api.spotify.com/v1/tracks/2Pocbh1NXgLr...
# 5XBqGcLYOZi8CEW83Ug7Fs  https://api.spotify.com/v1/tracks/5XBqGcLYOZi8...
# 5Hroj5K7vLpIG4FNCRIjbP  https://api.spotify.com/v1/tracks/5Hroj5K7vLpI...
# 7FjZU7XFs7P9jHI9Z0yRhK  https://api.spotify.com/v1/tracks/7FjZU7XFs7P9...
# 4Xx4oojaE3MlJKpgtilgp1  https://api.spotify.com/v1/tracks/4Xx4oojaE3Ml...
# 1xy4apMFecGGkgBeaHFZ2M  https://api.spotify.com/v1/tracks/1xy4apMFecGG...
# 34awK00Tgp6KW6jgxiY5mR  https://api.spotify.com/v1/tracks/34awK00Tgp6K...
# 5Ef2noaxqTAfa5gLVw05OJ  https://api.spotify.com/v1/tracks/5Ef2noaxqTAf...
# 6wljt66ynO2xWA1KE9Elu5  https://api.spotify.com/v1/tracks/6wljt66ynO2x...
# 18KOfFqQuVlcXhu0JRpUfN  https://api.spotify.com/v1/tracks/18KOfFqQuVlc...
# 0sooJd5WbNnnz5k6yO7FIQ  https://api.spotify.com/v1/tracks/0sooJd5WbNnn...
# 5fNDP3NTdE69szQHUl4fFr  https://api.spotify.com/v1/tracks/5fNDP3NTdE69...
#
#                                   type                                   uri  \
# id
# 14JzyD6FlBD5z0wV5P07YI  audio_features  spotify:track:14JzyD6FlBD5z0wV5P07YI
# 2aFC6EAvz25EC0osKd8PK0  audio_features  spotify:track:2aFC6EAvz25EC0osKd8PK0
# 0Peh9vSnImMMTznniOJcsj  audio_features  spotify:track:0Peh9vSnImMMTznniOJcsj
# 6usQ5BOBsRY5Dc49kwXsTw  audio_features  spotify:track:6usQ5BOBsRY5Dc49kwXsTw
# 4L2K7JKseFCBoHMZEAszW0  audio_features  spotify:track:4L2K7JKseFCBoHMZEAszW0
# 4CYBfRX3oEPni9Elqm8Bnt  audio_features  spotify:track:4CYBfRX3oEPni9Elqm8Bnt
# 1VbhR6D6zUoSTBzvnRonXO  audio_features  spotify:track:1VbhR6D6zUoSTBzvnRonXO
# 3sfepRu8KYCfKoPOsH6ym3  audio_features  spotify:track:3sfepRu8KYCfKoPOsH6ym3
# 6k8kLJFmWkHaTbSLUhJ3H0  audio_features  spotify:track:6k8kLJFmWkHaTbSLUhJ3H0
# 0c99BUd87HQfzgUUQqRyds  audio_features  spotify:track:0c99BUd87HQfzgUUQqRyds
# 0u2P5u6lvoDfwTYjAADbn4  audio_features  spotify:track:0u2P5u6lvoDfwTYjAADbn4
# 6mHw0o12JUfDodSxMwp8TI  audio_features  spotify:track:6mHw0o12JUfDodSxMwp8TI
# 0mel2N9Ws9r4yLQn5QE21Y  audio_features  spotify:track:0mel2N9Ws9r4yLQn5QE21Y
# 45iRSkMxq7aohzs3qu1ZtX  audio_features  spotify:track:45iRSkMxq7aohzs3qu1ZtX
# 3wF0zyjQ6FKLK4vFxcMojP  audio_features  spotify:track:3wF0zyjQ6FKLK4vFxcMojP
# 1F7ZElvJAvWKQ7UaPXg9cF  audio_features  spotify:track:1F7ZElvJAvWKQ7UaPXg9cF
# 3EPXxR3ImUwfayaurPi3cm  audio_features  spotify:track:3EPXxR3ImUwfayaurPi3cm
# 0pQlcs8qsOOLphM8laWr5v  audio_features  spotify:track:0pQlcs8qsOOLphM8laWr5v
# 1fYouLdK3PkOMPnx4CPxTY  audio_features  spotify:track:1fYouLdK3PkOMPnx4CPxTY
# 5Cv1xqpyciZZuHHR7xr2l0  audio_features  spotify:track:5Cv1xqpyciZZuHHR7xr2l0
# 6PmhCEPMjhSo9j8hz767xy  audio_features  spotify:track:6PmhCEPMjhSo9j8hz767xy
# 6r44uyKRo3jKFRkThTZBXu  audio_features  spotify:track:6r44uyKRo3jKFRkThTZBXu
# 5vmSMCACbvvNyj71zAMRQ9  audio_features  spotify:track:5vmSMCACbvvNyj71zAMRQ9
# 22uyZjmZR0DX8FyrIwQl35  audio_features  spotify:track:22uyZjmZR0DX8FyrIwQl35
# 4sVnlrSGaRwnBaj35C2wXu  audio_features  spotify:track:4sVnlrSGaRwnBaj35C2wXu
# 3nVzM4S7hHDbyZMGyvtJdX  audio_features  spotify:track:3nVzM4S7hHDbyZMGyvtJdX
# 0u4rkpmNtgcFxYHepnVF4v  audio_features  spotify:track:0u4rkpmNtgcFxYHepnVF4v
# 4bPkBHKLKd9WHizsvM2zV3  audio_features  spotify:track:4bPkBHKLKd9WHizsvM2zV3
# 5EKm2REw8HdwoadlQKffFJ  audio_features  spotify:track:5EKm2REw8HdwoadlQKffFJ
# 5NRl32BO29q8xtWFvOlHZE  audio_features  spotify:track:5NRl32BO29q8xtWFvOlHZE
# ...                                ...                                   ...
# 5eGX87IiKsGuzS3iw4CfCX  audio_features  spotify:track:5eGX87IiKsGuzS3iw4CfCX
# 6QgjcU0zLnzq5OrUoSZ3OK  audio_features  spotify:track:6QgjcU0zLnzq5OrUoSZ3OK
# 5ntzu58JfhdotnHWSJR4mj  audio_features  spotify:track:5ntzu58JfhdotnHWSJR4mj
# 6DlxVlOMWDG71sNyaJtmTy  audio_features  spotify:track:6DlxVlOMWDG71sNyaJtmTy
# 2Gy7qnDwt8Z3MNxqat4CsK  audio_features  spotify:track:2Gy7qnDwt8Z3MNxqat4CsK
# 0KXDqw7VbJh2EMAE6hbqLA  audio_features  spotify:track:0KXDqw7VbJh2EMAE6hbqLA
# 0Hw6SCrtU9pFCjgAONpnGZ  audio_features  spotify:track:0Hw6SCrtU9pFCjgAONpnGZ
# 0hK0PTJdd4Jx6Ryl4t8jTi  audio_features  spotify:track:0hK0PTJdd4Jx6Ryl4t8jTi
# 2ewW50QGufVvqP959lB8F9  audio_features  spotify:track:2ewW50QGufVvqP959lB8F9
# 3VKDOXkmTHt4Xa78U4dbDp  audio_features  spotify:track:3VKDOXkmTHt4Xa78U4dbDp
# 5yjOhc3JKrznGouRHMagoJ  audio_features  spotify:track:5yjOhc3JKrznGouRHMagoJ
# 2udw7RDkldLFIPG9WYdVtT  audio_features  spotify:track:2udw7RDkldLFIPG9WYdVtT
# 0Y2SrByf4G3kbq2nBEHQRn  audio_features  spotify:track:0Y2SrByf4G3kbq2nBEHQRn
# 3T4UodGkfZObJ43RtA5KFU  audio_features  spotify:track:3T4UodGkfZObJ43RtA5KFU
# 3FNY26zMg3Zfe5Cbyu45uu  audio_features  spotify:track:3FNY26zMg3Zfe5Cbyu45uu
# 5PyRffCCs2KPPL5LFDGEs5  audio_features  spotify:track:5PyRffCCs2KPPL5LFDGEs5
# 7dhh5MGe898uMm7TrCUvwj  audio_features  spotify:track:7dhh5MGe898uMm7TrCUvwj
# 01k24g94i1JvkFLQmVEdCd  audio_features  spotify:track:01k24g94i1JvkFLQmVEdCd
# 2Pocbh1NXgLruVbUAlBh54  audio_features  spotify:track:2Pocbh1NXgLruVbUAlBh54
# 5XBqGcLYOZi8CEW83Ug7Fs  audio_features  spotify:track:5XBqGcLYOZi8CEW83Ug7Fs
# 5Hroj5K7vLpIG4FNCRIjbP  audio_features  spotify:track:5Hroj5K7vLpIG4FNCRIjbP
# 7FjZU7XFs7P9jHI9Z0yRhK  audio_features  spotify:track:7FjZU7XFs7P9jHI9Z0yRhK
# 4Xx4oojaE3MlJKpgtilgp1  audio_features  spotify:track:4Xx4oojaE3MlJKpgtilgp1
# 1xy4apMFecGGkgBeaHFZ2M  audio_features  spotify:track:1xy4apMFecGGkgBeaHFZ2M
# 34awK00Tgp6KW6jgxiY5mR  audio_features  spotify:track:34awK00Tgp6KW6jgxiY5mR
# 5Ef2noaxqTAfa5gLVw05OJ  audio_features  spotify:track:5Ef2noaxqTAfa5gLVw05OJ
# 6wljt66ynO2xWA1KE9Elu5  audio_features  spotify:track:6wljt66ynO2xWA1KE9Elu5
# 18KOfFqQuVlcXhu0JRpUfN  audio_features  spotify:track:18KOfFqQuVlcXhu0JRpUfN
# 0sooJd5WbNnnz5k6yO7FIQ  audio_features  spotify:track:0sooJd5WbNnnz5k6yO7FIQ
# 5fNDP3NTdE69szQHUl4fFr  audio_features  spotify:track:5fNDP3NTdE69szQHUl4fFr
#
#                         valence  playlist_name  \
# id
# 14JzyD6FlBD5z0wV5P07YI   0.2050     Sad Songs😔
# 2aFC6EAvz25EC0osKd8PK0   0.0391     Sad Songs😔
# 0Peh9vSnImMMTznniOJcsj   0.3370     Sad Songs😔
# 6usQ5BOBsRY5Dc49kwXsTw   0.1420     Sad Songs😔
# 4L2K7JKseFCBoHMZEAszW0   0.0935     Sad Songs😔
# 4CYBfRX3oEPni9Elqm8Bnt   0.3700     Sad Songs😔
# 1VbhR6D6zUoSTBzvnRonXO   0.5190     Sad Songs😔
# 3sfepRu8KYCfKoPOsH6ym3   0.2620     Sad Songs😔
# 6k8kLJFmWkHaTbSLUhJ3H0   0.1690     Sad Songs😔
# 0c99BUd87HQfzgUUQqRyds   0.3290     Sad Songs😔
# 0u2P5u6lvoDfwTYjAADbn4   0.1200     Sad Songs😔
# 6mHw0o12JUfDodSxMwp8TI   0.0565     Sad Songs😔
# 0mel2N9Ws9r4yLQn5QE21Y   0.5400     Sad Songs😔
# 45iRSkMxq7aohzs3qu1ZtX   0.4950     Sad Songs😔
# 3wF0zyjQ6FKLK4vFxcMojP   0.3650     Sad Songs😔
# 1F7ZElvJAvWKQ7UaPXg9cF   0.5190     Sad Songs😔
# 3EPXxR3ImUwfayaurPi3cm   0.4430     Sad Songs😔
# 0pQlcs8qsOOLphM8laWr5v   0.0791     Sad Songs😔
# 1fYouLdK3PkOMPnx4CPxTY   0.1300     Sad Songs😔
# 5Cv1xqpyciZZuHHR7xr2l0   0.6910     Sad Songs😔
# 6PmhCEPMjhSo9j8hz767xy   0.1340     Sad Songs😔
# 6r44uyKRo3jKFRkThTZBXu   0.5010     Sad Songs😔
# 5vmSMCACbvvNyj71zAMRQ9   0.5070     Sad Songs😔
# 22uyZjmZR0DX8FyrIwQl35   0.2030     Sad Songs😔
# 4sVnlrSGaRwnBaj35C2wXu   0.3720     Sad Songs😔
# 3nVzM4S7hHDbyZMGyvtJdX   0.2440     Sad Songs😔
# 0u4rkpmNtgcFxYHepnVF4v   0.0351     Sad Songs😔
# 4bPkBHKLKd9WHizsvM2zV3   0.0395     Sad Songs😔
# 5EKm2REw8HdwoadlQKffFJ   0.1990     Sad Songs😔
# 5NRl32BO29q8xtWFvOlHZE   0.2850     Sad Songs😔
# ...                         ...            ...
# 5eGX87IiKsGuzS3iw4CfCX   0.5880  Wake Up Happy
# 6QgjcU0zLnzq5OrUoSZ3OK   0.7540  Wake Up Happy
# 5ntzu58JfhdotnHWSJR4mj   0.8880  Wake Up Happy
# 6DlxVlOMWDG71sNyaJtmTy   0.6760  Wake Up Happy
# 2Gy7qnDwt8Z3MNxqat4CsK   0.7200  Wake Up Happy
# 0KXDqw7VbJh2EMAE6hbqLA   0.4670  Wake Up Happy
# 0Hw6SCrtU9pFCjgAONpnGZ   0.9290  Wake Up Happy
# 0hK0PTJdd4Jx6Ryl4t8jTi   0.8260  Wake Up Happy
# 2ewW50QGufVvqP959lB8F9   0.2320  Wake Up Happy
# 3VKDOXkmTHt4Xa78U4dbDp   0.4130  Wake Up Happy
# 5yjOhc3JKrznGouRHMagoJ   0.3850  Wake Up Happy
# 2udw7RDkldLFIPG9WYdVtT   0.9520  Wake Up Happy
# 0Y2SrByf4G3kbq2nBEHQRn   0.5520  Wake Up Happy
# 3T4UodGkfZObJ43RtA5KFU   0.6240  Wake Up Happy
# 3FNY26zMg3Zfe5Cbyu45uu   0.3570  Wake Up Happy
# 5PyRffCCs2KPPL5LFDGEs5   0.4400  Wake Up Happy
# 7dhh5MGe898uMm7TrCUvwj   0.4350  Wake Up Happy
# 01k24g94i1JvkFLQmVEdCd   0.6180  Wake Up Happy
# 2Pocbh1NXgLruVbUAlBh54   0.9740  Wake Up Happy
# 5XBqGcLYOZi8CEW83Ug7Fs   0.2790  Wake Up Happy
# 5Hroj5K7vLpIG4FNCRIjbP   0.5210  Wake Up Happy
# 7FjZU7XFs7P9jHI9Z0yRhK   0.7610  Wake Up Happy
# 4Xx4oojaE3MlJKpgtilgp1   0.5410  Wake Up Happy
# 1xy4apMFecGGkgBeaHFZ2M   0.3860  Wake Up Happy
# 34awK00Tgp6KW6jgxiY5mR   0.5700  Wake Up Happy
# 5Ef2noaxqTAfa5gLVw05OJ   0.6110  Wake Up Happy
# 6wljt66ynO2xWA1KE9Elu5   0.9610  Wake Up Happy
# 18KOfFqQuVlcXhu0JRpUfN   0.6420  Wake Up Happy
# 0sooJd5WbNnnz5k6yO7FIQ   0.5810  Wake Up Happy
# 5fNDP3NTdE69szQHUl4fFr   0.9630  Wake Up Happy
#
#                                                             playlist_desc  \
# id
# 14JzyD6FlBD5z0wV5P07YI  Hey my lovely listeners! Heres a few songs whi...
# 2aFC6EAvz25EC0osKd8PK0  Hey my lovely listeners! Heres a few songs whi...
# 0Peh9vSnImMMTznniOJcsj  Hey my lovely listeners! Heres a few songs whi...
# 6usQ5BOBsRY5Dc49kwXsTw  Hey my lovely listeners! Heres a few songs whi...
# 4L2K7JKseFCBoHMZEAszW0  Hey my lovely listeners! Heres a few songs whi...
# 4CYBfRX3oEPni9Elqm8Bnt  Hey my lovely listeners! Heres a few songs whi...
# 1VbhR6D6zUoSTBzvnRonXO  Hey my lovely listeners! Heres a few songs whi...
# 3sfepRu8KYCfKoPOsH6ym3  Hey my lovely listeners! Heres a few songs whi...
# 6k8kLJFmWkHaTbSLUhJ3H0  Hey my lovely listeners! Heres a few songs whi...
# 0c99BUd87HQfzgUUQqRyds  Hey my lovely listeners! Heres a few songs whi...
# 0u2P5u6lvoDfwTYjAADbn4  Hey my lovely listeners! Heres a few songs whi...
# 6mHw0o12JUfDodSxMwp8TI  Hey my lovely listeners! Heres a few songs whi...
# 0mel2N9Ws9r4yLQn5QE21Y  Hey my lovely listeners! Heres a few songs whi...
# 45iRSkMxq7aohzs3qu1ZtX  Hey my lovely listeners! Heres a few songs whi...
# 3wF0zyjQ6FKLK4vFxcMojP  Hey my lovely listeners! Heres a few songs whi...
# 1F7ZElvJAvWKQ7UaPXg9cF  Hey my lovely listeners! Heres a few songs whi...
# 3EPXxR3ImUwfayaurPi3cm  Hey my lovely listeners! Heres a few songs whi...
# 0pQlcs8qsOOLphM8laWr5v  Hey my lovely listeners! Heres a few songs whi...
# 1fYouLdK3PkOMPnx4CPxTY  Hey my lovely listeners! Heres a few songs whi...
# 5Cv1xqpyciZZuHHR7xr2l0  Hey my lovely listeners! Heres a few songs whi...
# 6PmhCEPMjhSo9j8hz767xy  Hey my lovely listeners! Heres a few songs whi...
# 6r44uyKRo3jKFRkThTZBXu  Hey my lovely listeners! Heres a few songs whi...
# 5vmSMCACbvvNyj71zAMRQ9  Hey my lovely listeners! Heres a few songs whi...
# 22uyZjmZR0DX8FyrIwQl35  Hey my lovely listeners! Heres a few songs whi...
# 4sVnlrSGaRwnBaj35C2wXu  Hey my lovely listeners! Heres a few songs whi...
# 3nVzM4S7hHDbyZMGyvtJdX  Hey my lovely listeners! Heres a few songs whi...
# 0u4rkpmNtgcFxYHepnVF4v  Hey my lovely listeners! Heres a few songs whi...
# 4bPkBHKLKd9WHizsvM2zV3  Hey my lovely listeners! Heres a few songs whi...
# 5EKm2REw8HdwoadlQKffFJ  Hey my lovely listeners! Heres a few songs whi...
# 5NRl32BO29q8xtWFvOlHZE  Hey my lovely listeners! Heres a few songs whi...
# ...                                                                   ...
# 5eGX87IiKsGuzS3iw4CfCX  Set the mood of your day with these awesome, h...
# 6QgjcU0zLnzq5OrUoSZ3OK  Set the mood of your day with these awesome, h...
# 5ntzu58JfhdotnHWSJR4mj  Set the mood of your day with these awesome, h...
# 6DlxVlOMWDG71sNyaJtmTy  Set the mood of your day with these awesome, h...
# 2Gy7qnDwt8Z3MNxqat4CsK  Set the mood of your day with these awesome, h...
# 0KXDqw7VbJh2EMAE6hbqLA  Set the mood of your day with these awesome, h...
# 0Hw6SCrtU9pFCjgAONpnGZ  Set the mood of your day with these awesome, h...
# 0hK0PTJdd4Jx6Ryl4t8jTi  Set the mood of your day with these awesome, h...
# 2ewW50QGufVvqP959lB8F9  Set the mood of your day with these awesome, h...
# 3VKDOXkmTHt4Xa78U4dbDp  Set the mood of your day with these awesome, h...
# 5yjOhc3JKrznGouRHMagoJ  Set the mood of your day with these awesome, h...
# 2udw7RDkldLFIPG9WYdVtT  Set the mood of your day with these awesome, h...
# 0Y2SrByf4G3kbq2nBEHQRn  Set the mood of your day with these awesome, h...
# 3T4UodGkfZObJ43RtA5KFU  Set the mood of your day with these awesome, h...
# 3FNY26zMg3Zfe5Cbyu45uu  Set the mood of your day with these awesome, h...
# 5PyRffCCs2KPPL5LFDGEs5  Set the mood of your day with these awesome, h...
# 7dhh5MGe898uMm7TrCUvwj  Set the mood of your day with these awesome, h...
# 01k24g94i1JvkFLQmVEdCd  Set the mood of your day with these awesome, h...
# 2Pocbh1NXgLruVbUAlBh54  Set the mood of your day with these awesome, h...
# 5XBqGcLYOZi8CEW83Ug7Fs  Set the mood of your day with these awesome, h...
# 5Hroj5K7vLpIG4FNCRIjbP  Set the mood of your day with these awesome, h...
# 7FjZU7XFs7P9jHI9Z0yRhK  Set the mood of your day with these awesome, h...
# 4Xx4oojaE3MlJKpgtilgp1  Set the mood of your day with these awesome, h...
# 1xy4apMFecGGkgBeaHFZ2M  Set the mood of your day with these awesome, h...
# 34awK00Tgp6KW6jgxiY5mR  Set the mood of your day with these awesome, h...
# 5Ef2noaxqTAfa5gLVw05OJ  Set the mood of your day with these awesome, h...
# 6wljt66ynO2xWA1KE9Elu5  Set the mood of your day with these awesome, h...
# 18KOfFqQuVlcXhu0JRpUfN  Set the mood of your day with these awesome, h...
# 0sooJd5WbNnnz5k6yO7FIQ  Set the mood of your day with these awesome, h...
# 5fNDP3NTdE69szQHUl4fFr  Set the mood of your day with these awesome, h...
#
#                         label clusters
# id
# 14JzyD6FlBD5z0wV5P07YI    sad        1
# 2aFC6EAvz25EC0osKd8PK0    sad        1
# 0Peh9vSnImMMTznniOJcsj    sad        1
# 6usQ5BOBsRY5Dc49kwXsTw    sad        1
# 4L2K7JKseFCBoHMZEAszW0    sad        1
# 4CYBfRX3oEPni9Elqm8Bnt    sad        1
# 1VbhR6D6zUoSTBzvnRonXO    sad        0
# 3sfepRu8KYCfKoPOsH6ym3    sad        1
# 6k8kLJFmWkHaTbSLUhJ3H0    sad        1
# 0c99BUd87HQfzgUUQqRyds    sad        1
# 0u2P5u6lvoDfwTYjAADbn4    sad        1
# 6mHw0o12JUfDodSxMwp8TI    sad        1
# 0mel2N9Ws9r4yLQn5QE21Y    sad        1
# 45iRSkMxq7aohzs3qu1ZtX    sad        1
# 3wF0zyjQ6FKLK4vFxcMojP    sad        1
# 1F7ZElvJAvWKQ7UaPXg9cF    sad        0
# 3EPXxR3ImUwfayaurPi3cm    sad        1
# 0pQlcs8qsOOLphM8laWr5v    sad        1
# 1fYouLdK3PkOMPnx4CPxTY    sad        1
# 5Cv1xqpyciZZuHHR7xr2l0    sad        1
# 6PmhCEPMjhSo9j8hz767xy    sad        1
# 6r44uyKRo3jKFRkThTZBXu    sad        1
# 5vmSMCACbvvNyj71zAMRQ9    sad        1
# 22uyZjmZR0DX8FyrIwQl35    sad        1
# 4sVnlrSGaRwnBaj35C2wXu    sad        1
# 3nVzM4S7hHDbyZMGyvtJdX    sad        0
# 0u4rkpmNtgcFxYHepnVF4v    sad        1
# 4bPkBHKLKd9WHizsvM2zV3    sad        1
# 5EKm2REw8HdwoadlQKffFJ    sad        1
# 5NRl32BO29q8xtWFvOlHZE    sad        1
# ...                       ...      ...
# 5eGX87IiKsGuzS3iw4CfCX  happy        0
# 6QgjcU0zLnzq5OrUoSZ3OK  happy        0
# 5ntzu58JfhdotnHWSJR4mj  happy        0
# 6DlxVlOMWDG71sNyaJtmTy  happy        0
# 2Gy7qnDwt8Z3MNxqat4CsK  happy        1
# 0KXDqw7VbJh2EMAE6hbqLA  happy        0
# 0Hw6SCrtU9pFCjgAONpnGZ  happy        0
# 0hK0PTJdd4Jx6Ryl4t8jTi  happy        0
# 2ewW50QGufVvqP959lB8F9  happy        0
# 3VKDOXkmTHt4Xa78U4dbDp  happy        0
# 5yjOhc3JKrznGouRHMagoJ  happy        0
# 2udw7RDkldLFIPG9WYdVtT  happy        0
# 0Y2SrByf4G3kbq2nBEHQRn  happy        0
# 3T4UodGkfZObJ43RtA5KFU  happy        0
# 3FNY26zMg3Zfe5Cbyu45uu  happy        0
# 5PyRffCCs2KPPL5LFDGEs5  happy        0
# 7dhh5MGe898uMm7TrCUvwj  happy        0
# 01k24g94i1JvkFLQmVEdCd  happy        0
# 2Pocbh1NXgLruVbUAlBh54  happy        0
# 5XBqGcLYOZi8CEW83Ug7Fs  happy        0
# 5Hroj5K7vLpIG4FNCRIjbP  happy        0
# 7FjZU7XFs7P9jHI9Z0yRhK  happy        0
# 4Xx4oojaE3MlJKpgtilgp1  happy        0
# 1xy4apMFecGGkgBeaHFZ2M  happy        0
# 34awK00Tgp6KW6jgxiY5mR  happy        0
# 5Ef2noaxqTAfa5gLVw05OJ  happy        0
# 6wljt66ynO2xWA1KE9Elu5  happy        0
# 18KOfFqQuVlcXhu0JRpUfN  happy        0
# 0sooJd5WbNnnz5k6yO7FIQ  happy        0
# 5fNDP3NTdE69szQHUl4fFr  happy        0
#
# [290 rows x 26 columns]

# %% [markdown]
# Perform PCA analysis

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# combine two playlists

# get the x_cols
x_cols = df_combined[feature_names]

# model
scaler = StandardScaler()
pca = PCA()

pipeline = make_pipeline(scaler, pca)

pca_features = pipeline.fit_transform(x_cols)

# get the samples for the PCA components
xs = pca_features[:,0]
ys = pca_features[:,1]

# create the dataframe

df_pca = pd.DataFrame({'track':df_combined['name'],
                       'clusters':df_combined['clusters'], 
                       'label':df_combined['label'], 
                       'x':xs,'y':ys})

# plot a scatterplot
plt.scatter(pca_features[:, 0], pca_features[:, 1],
            c=df_pca.clusters, edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('viridis', 2))
plt.xlabel('component 1')
plt.ylabel('component 2')
cbar=plt.colorbar(ticks=[0,1])
cbar.ax.set_yticklabels(['Sad', 'Happy'])
plt.show()
# Out:
# c:\users\henta\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\henta\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
df_pca['label_num']= df_pca['label']=='sad'

plt.scatter(pca_features[:, 0], pca_features[:, 1],
            c=df_pca.label_num, edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('viridis', 2))
plt.xlabel('component 1')
plt.ylabel('component 2')
cbar=plt.colorbar(ticks=[0,1])
cbar.ax.set_yticklabels(['Sad', 'Happy'])
plt.show()

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler, pca)

# Fit the pipeline to 'samples'
pipeline.fit(x_cols)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()
# Out:
# c:\users\henta\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\henta\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# What should be the instrinsic dimensionality? 1, 2, 5, 8?
